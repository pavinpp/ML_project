# %% [markdown]
# # Feature Engineering & Data Preparation (Part 3)
#
# ## Objective
# In this notebook, we build the final dataset used to train our machine learning model. We need to create "features" (variables) that help the model predict crop yield.
#
# We will construct three main types of features:
# 1.  **Historical Yields (Lag Features):** Using the yield from previous years (1, 3, and 5-year averages) to predict the future.
# 2.  **Seasonal Weather:** Aggregating monthly weather data into seasonal averages (Winter, Spring, Summer, Fall) and shifting them to align with the crop year.
# 3.  **Farming Inputs & Location:** Adding fertilizer/pesticide usage and GPS coordinates (Latitude/Longitude).
#
# The final result will be saved as `x_features.parquet`.

# %%
import pandas as pd
import numpy as np
from functools import reduce

# %% [markdown]
# ### 1. Load and Clean Data
# We import the standard libraries and load the two datasets we cleaned in Part 1:
# * `nasa_df.parquet`: Our weather data.
# * `label_yield.parquet`: Our target crop yield data.
#
# We also do a quick cleanup of the crop names to ensure they match perfectly.

# %%
# Load datasets
nasa_df = pd.read_parquet('Parquet/nasa_df.parquet')
label_yield = pd.read_parquet('Parquet/label_yield.parquet')

# Clean crop names for consistent column naming
label_yield['item'] = label_yield['item'].str.replace(r'[^0-9a-zA-Z ]', '', regex=True)
label_yield['item'] = label_yield['item'].str.replace(" ", "_").str.lower()

# Generate a list of unique crops for iteration
crop_list = list(label_yield['item'].unique())

# %% [markdown]
# ### 2. Create "Lag" Features (Past Yields)
# Agricultural production often follows trends. If a farm was productive last year, it is likely to be productive this year.
#
# We define a function `past_n_year_avg` that calculates the average yield for:
# * **Lag 1:** The yield 1 year ago.
# * **Lag 3:** The average yield of the last 3 years.
# * **Lag 5:** The average yield of the last 5 years.
#
# This gives the model a "memory" of recent performance.

# %%
def past_n_year_avg(df, crop_type, n):
    """
    Compute past-n-year average yield strictly for N full years.
    If less than N full past years exist, return NaN.
    """
    d = df[df['item'] == crop_type].copy()
    d['year'] = pd.to_datetime(d['year']).dt.year
    d = d.sort_values(['area', 'year'])

    def compute_avg(g):
        yrs = g['year'].values
        lbl = g['label'].values
        res = []

        for y in yrs:
            # past N years only
            mask = (yrs >= y - n) & (yrs < y)
            vals = lbl[mask]

            # strict requirement: must have exactly N rows
            if len(vals) == n:
                res.append(vals.mean())
            else:
                res.append(np.nan)

        return pd.Series(res, index=g.index)

    d[f'avg_yield_{crop_type}_{n}y'] = (
        d.groupby('area', group_keys=False)
         .apply(compute_avg, include_groups=False)
    )

    return d[['year', 'area', f'avg_yield_{crop_type}_{n}y']]

# %% [markdown]
# #### Generate Lags for All Crops
# We run our function for every crop in our list and merge the results into a single dataframe called `features_lag_yield`.

# %%
# Iterate through all crops and generate lag features
dfs = []
for crop in crop_list:
    for n in [1, 3, 5]:
        dfs.append(past_n_year_avg(label_yield, crop, n))

# Merge all crop features into a single dataframe
features_lag_yield = reduce(
    lambda left, right: pd.merge(left, right, how='left', on=['year', 'area']),
    dfs
)

# %% [markdown]
# ### 3. Weather Feature Engineering
# Crops don't care about "January" or "February" specifically; they care about growing seasons (Spring, Summer, Autumn, Winter).
#
# We process the weather data as follows:
# 1.  **Group by Season:** We combine months into four seasons (e.g., Dec-Feb = Winter).
# 2.  **Aggregate:** We calculate the **Total Rain** (Sum) and **Average Temperature/Sunlight** (Mean) for each season.
# 3.  **Lag by 1 Year:** We align the weather from the *previous* year to the *current* crop year. This allows us to predict yields before the current season is even finished.

# %%
def prep_seasonal_weather_lag1year(nasa_df, var_list=['rain','solar','temp']):
    """
    Computes seasonal lag-1 weather features:
    - Rain -> SUM
    - Solar, Temp -> AVG
    Strict: require all months for the season/annual, else NaN
    """
    nasa_df['date'] = pd.to_datetime(nasa_df['date'])
    nasa_df['year'] = nasa_df['date'].dt.year
    nasa_df['month'] = nasa_df['date'].dt.month
    
    all_features = None
    
    for var in var_list:
        # pivot
        p = nasa_df.pivot_table(
            index=['area','year'],
            columns='month',
            values=var
        ).reset_index()
        
        # rename months
        month_map = {m: f"{var}_{pd.Timestamp(2000,m,1).strftime('%b').lower()}" for m in range(1,13)}
        p = p.rename(columns=month_map)

        # lag 1 year
        p['year'] = p['year'] + 1

        # ensure all months exist
        months = [f"{var}_{pd.Timestamp(2000,m,1).strftime('%b').lower()}" for m in range(1,13)]
        for col in months:
            if col not in p.columns:
                p[col] = pd.NA

        # define seasons
        winter = [f"{var}_jan", f"{var}_feb", f"{var}_dec"]
        spring = [f"{var}_mar", f"{var}_apr", f"{var}_may"]
        summer = [f"{var}_jun", f"{var}_jul", f"{var}_aug"]
        autumn = [f"{var}_sep", f"{var}_oct", f"{var}_nov"]

        # aggregation functions
        if var == 'rain':
            # strict sum
            agg_func = lambda df, cols: df[cols].where(df[cols].notna().all(axis=1), pd.NA).sum(axis=1)
        else:
            # strict avg
            agg_func = lambda df, cols: df[cols].where(df[cols].notna().all(axis=1), pd.NA).mean(axis=1)

        p[f"{'sum' if var=='rain' else 'avg'}_{var}_winter"] = agg_func(p, winter)
        p[f"{'sum' if var=='rain' else 'avg'}_{var}_spring"] = agg_func(p, spring)
        p[f"{'sum' if var=='rain' else 'avg'}_{var}_summer"] = agg_func(p, summer)
        p[f"{'sum' if var=='rain' else 'avg'}_{var}_autumn"] = agg_func(p, autumn)
        p[f"{'sum' if var=='rain' else 'avg'}_{var}_annual"] = agg_func(p, months)

        # keep relevant columns
        cols_keep = ['area','year'] + [
            f"{'sum' if var=='rain' else 'avg'}_{var}_{s}" for s in ['winter','spring','summer','autumn','annual']
        ]
        p = p[cols_keep]

        # merge
        all_features = p if all_features is None else all_features.merge(p, on=['area','year'], how='outer')

    return all_features

# %%
# Process weather features
nasa_f = prep_seasonal_weather_lag1year(nasa_df, var_list=['rain','solar','temp'])

# Verify
print(nasa_f.columns.tolist())
# Out:
# ['area', 'year', 'sum_rain_winter', 'sum_rain_spring', 'sum_rain_summer', 'sum_rain_autumn', 'sum_rain_annual', 'avg_solar_winter', 'avg_solar_spring', 'avg_solar_summer', 'avg_solar_autumn', 'avg_solar_annual', 'avg_temp_winter', 'avg_temp_spring', 'avg_temp_summer', 'avg_temp_autumn', 'avg_temp_annual']

# %% [markdown]
# ### 4. Add Location Data (Geospatial)
#  Geography plays a huge role in agriculture. We load a separate file containing the **Latitude and Longitude** for each country. This helps the model understand that "Thailand" and "Vietnam" are neighbors and might share similar traits.

# %%
# Load geospatial data (Assuming 'lat_long.csv' exists in Data folder)
latlong = pd.read_csv('Data/coordinates.csv')

# Clean and standardize formatting
latlong['area'] = latlong['Area'].str.replace(' ', '_')
latlong = latlong[['area', 'latitude', 'longitude']]

# Display sample to verify structure
latlong.head()
# Out:
#         area  latitude  longitude
# 0    Albania     41.33      19.82
# 1    Algeria     28.03       1.66
# 2     Angola    -11.20      17.87
# 3  Argentina    -38.42     -63.62
# 4    Armenia     40.07      45.04

# %% [markdown]
# ### 5. Add Farming Inputs (Fertilizers & Pesticides)
# We include data on how much fertilizer and pesticide was used.
# * **Logic:** We shift this data by 1 year (`Lag 1`).
# * **Reason:** Farmers often plan their budget based on the previous year's usage. Using last year's data makes our prediction more practical for early forecasting.

# %%
# 1. Load the farming data
farming_df = pd.read_parquet('Parquet/farming_df.parquet')

# 2. Ensure 'year' is in datetime format for accurate date shifting
farming_df['year'] = pd.to_datetime(farming_df['year'])

# 3. Create Lag Features (Shift Year Forward by 1)
# Logic: We use 2020's pesticides for the 2021 yield row.
farming_df['year'] = farming_df['year'] + pd.DateOffset(years=1)

# === FIX START ===
# 4. Convert 'year' back to an integer to match x_features
farming_df['year'] = farming_df['year'].dt.year
# === FIX END ===

# 5. Rename columns to indicate they are lagged
farming_df = farming_df.rename(columns={
    'pesticides': 'pesticides_lag1',
    'fertilizer': 'fertilizer_lag1'
})

# %% [markdown]
# ### 6. Final Merge and Save
# We combine all our new features into one master dataset:
# * **Yield Lags** + **Seasonal Weather** + **Farming Inputs** + **Location**
#
# We filter out data before 1982 (since we don't have enough history to calculate the 5-year lag for those early years) and save the final file as `x_features_v2.parquet`.

# %%
# Merge Yield Lags with Weather Data
x_features = features_lag_yield.merge(
    nasa_f, on=['year', 'area'], how='left'
)

# 7. Merge with Farming Data
# Now both dataframes have 'year' as an integer
x_features = x_features.merge(
    farming_df, on=['year', 'area'], how='left'
)

# Merge with Geospatial Data
x_features = x_features.merge(
    latlong, on=['area'], how='left'
)


# Prevent pandas from hiding columns
pd.set_option('display.max_columns', None)

# Show first 20 rows for Thailand
x_features[x_features['area'] == 'Thailand'].head(20)
# Out:
#       year      area  avg_yield_maize_corn_1y  avg_yield_maize_corn_3y  \
# 7309  1970  Thailand                      NaN                      NaN
# 7310  1971  Thailand                   2587.7                      NaN
# 7311  1972  Thailand                   2421.1                      NaN
# 7312  1973  Thailand                   1414.0              2140.933333
# 7313  1974  Thailand                   2227.6              2020.900000
# 7314  1975  Thailand                   2332.1              1991.233333
# 7315  1976  Thailand                   2375.2              2311.633333
# 7316  1977  Thailand                   2386.2              2364.500000
# 7317  1978  Thailand                   1717.7              2159.700000
# 7318  1979  Thailand                   2124.0              2075.966667
# 7319  1980  Thailand                   2010.3              1950.666667
# 7320  1981  Thailand                   2228.3              2120.866667
# 7321  1982  Thailand                   2353.8              2197.466667
# 7322  1983  Thailand                   2298.8              2293.633333
# 7323  1984  Thailand                   2267.4              2306.666667
# 7324  1985  Thailand                   2430.5              2332.233333
# 7325  1986  Thailand                   2571.9              2423.266667
# 7326  1987  Thailand                   2373.8              2458.733333
# 7327  1988  Thailand                   2048.6              2331.433333
# 7328  1989  Thailand                   2617.6              2346.666667
#
#       avg_yield_maize_corn_5y  avg_yield_other_vegetables_fresh_nec_1y  \
# 7309                      NaN                                      NaN
# 7310                      NaN                                   6181.1
# 7311                      NaN                                   6171.9
# 7312                      NaN                                   6210.9
# 7313                      NaN                                   6250.0
# 7314                  2196.50                                   6289.1
# 7315                  2154.00                                   6328.1
# 7316                  2147.02                                   6367.2
# 7317                  2207.76                                   6406.3
# 7318                  2187.04                                   6395.3
# 7319                  2122.68                                   6384.6
# 7320                  2093.30                                   6606.3
# 7321                  2086.82                                   6233.6
# 7322                  2203.04                                   6656.3
# 7323                  2231.72                                   6695.3
# 7324                  2315.76                                   6795.3
# 7325                  2384.48                                   7352.9
# 7326                  2388.48                                   7040.0
# 7327                  2338.44                                   7023.8
# 7328                  2408.48                                   7007.9
#
#       avg_yield_other_vegetables_fresh_nec_3y  \
# 7309                                      NaN
# 7310                                      NaN
# 7311                                      NaN
# 7312                              6187.966667
# 7313                              6210.933333
# 7314                              6250.000000
# 7315                              6289.066667
# 7316                              6328.133333
# 7317                              6367.200000
# 7318                              6389.600000
# 7319                              6395.400000
# 7320                              6462.066667
# 7321                              6408.166667
# 7322                              6498.733333
# 7323                              6528.400000
# 7324                              6715.633333
# 7325                              6947.833333
# 7326                              7062.733333
# 7327                              7138.900000
# 7328                              7023.900000
#
#       avg_yield_other_vegetables_fresh_nec_5y  avg_yield_potatoes_1y  \
# 7309                                      NaN                    NaN
# 7310                                      NaN                 8000.0
# 7311                                      NaN                 8000.0
# 7312                                      NaN                 8000.0
# 7313                                      NaN                 6540.6
# 7314                                  6220.60                 6532.2
# 7315                                  6250.00                 9944.5
# 7316                                  6289.06                 2573.1
# 7317                                  6328.14                10485.8
# 7318                                  6357.20                10361.3
# 7319                                  6376.30                 8937.6
# 7320                                  6431.94                 7762.5
# 7321                                  6405.22                 9987.5
# 7322                                  6455.22                11898.8
# 7323                                  6515.22                14216.0
# 7324                                  6597.36                10471.0
# 7325                                  6746.68                12284.1
# 7326                                  6907.96                12455.8
# 7327                                  6981.46                 7841.0
# 7328                                  7043.98                 8593.8
#
#       avg_yield_potatoes_3y  avg_yield_potatoes_5y  avg_yield_rice_1y  \
# 7309                    NaN                    NaN                NaN
# 7310                    NaN                    NaN             2020.7
# 7311                    NaN                    NaN             1936.9
# 7312            8000.000000                    NaN             1830.8
# 7313            7513.533333                    NaN             1924.2
# 7314            7024.266667                7414.56             1825.4
# 7315            7672.433333                7803.46             1830.8
# 7316            6349.933333                6718.08             1845.0
# 7317            7667.800000                7215.24             1591.0
# 7318            7806.733333                7979.38             1955.2
# 7319            9928.233333                8460.46             1820.9
# 7320            9020.466667                8024.06             1887.8
# 7321            8895.866667                9506.94             1952.1
# 7322            9882.933333                9789.54             1888.0
# 7323           12034.100000               10560.48             2035.1
# 7324           12195.266667               10867.16             2067.0
# 7325           12323.700000               11771.48             2060.8
# 7326           11736.966667               12265.14             2052.2
# 7327           10860.300000               11453.58             2014.7
# 7328            9630.200000               10329.14             2146.5
#
#       avg_yield_rice_3y  avg_yield_rice_5y  avg_yield_sugar_cane_1y  \
# 7309                NaN                NaN                      NaN
# 7310                NaN                NaN                  43149.5
# 7311                NaN                NaN                  47752.3
# 7312        1929.466667                NaN                  37373.9
# 7313        1897.300000                NaN                  52476.8
# 7314        1860.133333            1907.60                  51579.0
# 7315        1860.133333            1869.62                  48127.6
# 7316        1833.733333            1851.24                  53291.6
# 7317        1755.600000            1803.28                  52814.2
# 7318        1797.066667            1809.48                  33842.9
# 7319        1789.033333            1808.58                  40768.8
# 7320        1887.966667            1819.98                  30137.8
# 7321        1886.933333            1841.40                  43488.8
# 7322        1909.300000            1900.80                  49240.5
# 7323        1958.400000            1916.78                  42288.8
# 7324        1996.700000            1966.00                  44540.8
# 7325        2054.300000            2000.60                  47180.3
# 7326        2060.000000            2020.62                  44128.2
# 7327        2042.566667            2045.96                  47005.3
# 7328        2071.133333            2068.24                  47650.8
#
#       avg_yield_sugar_cane_3y  avg_yield_sugar_cane_5y  avg_yield_wheat_1y  \
# 7309                      NaN                      NaN                 NaN
# 7310                      NaN                      NaN                 NaN
# 7311                      NaN                      NaN                 NaN
# 7312             42758.566667                      NaN                 NaN
# 7313             45867.666667                      NaN                 NaN
# 7314             47143.233333                 46466.30                 NaN
# 7315             50727.800000                 47461.92                 NaN
# 7316             50999.400000                 48569.78                 NaN
# 7317             51411.133333                 51657.84                 NaN
# 7318             46649.566667                 47931.06                 NaN
# 7319             42475.300000                 45769.02                 NaN
# 7320             34916.500000                 42171.06                 NaN
# 7321             38131.800000                 40210.50                 NaN
# 7322             40955.700000                 39495.76                 NaN
# 7323             45006.033333                 41184.94                 NaN
# 7324             45356.700000                 41939.34                 NaN
# 7325             44669.966667                 45347.84                 NaN
# 7326             45283.100000                 45475.72              1193.2
# 7327             46104.600000                 45028.68              1250.0
# 7328             46261.433333                 46101.08               554.6
#
#       avg_yield_wheat_3y  avg_yield_wheat_5y  avg_yield_oil_palm_fruit_1y  \
# 7309                 NaN                 NaN                          NaN
# 7310                 NaN                 NaN                       5789.5
# 7311                 NaN                 NaN                       5789.5
# 7312                 NaN                 NaN                       5789.5
# 7313                 NaN                 NaN                       5833.3
# 7314                 NaN                 NaN                       5833.3
# 7315                 NaN                 NaN                       5823.5
# 7316                 NaN                 NaN                      10843.0
# 7317                 NaN                 NaN                      12207.4
# 7318                 NaN                 NaN                      10381.1
# 7319                 NaN                 NaN                      10281.0
# 7320                 NaN                 NaN                       9644.4
# 7321                 NaN                 NaN                      10116.5
# 7322                 NaN                 NaN                      10261.8
# 7323                 NaN                 NaN                       8361.8
# 7324                 NaN                 NaN                       8694.8
# 7325                 NaN                 NaN                      11445.5
# 7326                 NaN                 NaN                      11582.3
# 7327                 NaN                 NaN                      10531.2
# 7328          999.266667                 NaN                      10693.0
#
#       avg_yield_oil_palm_fruit_3y  avg_yield_oil_palm_fruit_5y  \
# 7309                          NaN                          NaN
# 7310                          NaN                          NaN
# 7311                          NaN                          NaN
# 7312                  5789.500000                          NaN
# 7313                  5804.100000                          NaN
# 7314                  5818.700000                      5807.02
# 7315                  5830.033333                      5813.82
# 7316                  7499.933333                      6824.52
# 7317                  9624.633333                      8108.10
# 7318                 11143.833333                      9017.66
# 7319                 10956.500000                      9907.20
# 7320                 10102.166667                     10671.38
# 7321                 10013.966667                     10526.08
# 7322                 10007.566667                     10136.96
# 7323                  9580.033333                      9733.10
# 7324                  9106.133333                      9415.86
# 7325                  9500.700000                      9776.08
# 7326                 10574.200000                     10069.24
# 7327                 11186.333333                     10123.12
# 7328                 10935.500000                     10589.36
#
#       avg_yield_barley_1y  avg_yield_barley_3y  avg_yield_barley_5y  \
# 7309                  NaN                  NaN                  NaN
# 7310                  NaN                  NaN                  NaN
# 7311                  NaN                  NaN                  NaN
# 7312                  NaN                  NaN                  NaN
# 7313                  NaN                  NaN                  NaN
# 7314                  NaN                  NaN                  NaN
# 7315                  NaN                  NaN                  NaN
# 7316                  NaN                  NaN                  NaN
# 7317                  NaN                  NaN                  NaN
# 7318                  NaN                  NaN                  NaN
# 7319                  NaN                  NaN                  NaN
# 7320                  NaN                  NaN                  NaN
# 7321                  NaN                  NaN                  NaN
# 7322                  NaN                  NaN                  NaN
# 7323                  NaN                  NaN                  NaN
# 7324                  NaN                  NaN                  NaN
# 7325                  NaN                  NaN                  NaN
# 7326                  NaN                  NaN                  NaN
# 7327                  NaN                  NaN                  NaN
# 7328                  NaN                  NaN                  NaN
#
#       avg_yield_soya_beans_1y  avg_yield_soya_beans_3y  \
# 7309                      NaN                      NaN
# 7310                    875.0                      NaN
# 7311                   1007.0                      NaN
# 7312                    940.3               940.766667
# 7313                   1001.6               982.966667
# 7314                    871.6               937.833333
# 7315                   1027.6               966.933333
# 7316                   1209.6              1036.266667
# 7317                    736.5               991.233333
# 7318                   1093.7              1013.266667
# 7319                   1017.6               949.266667
# 7320                    949.8              1020.366667
# 7321                   1052.0              1006.466667
# 7322                   1123.6              1041.800000
# 7323                   1149.3              1108.300000
# 7324                   1275.4              1182.766667
# 7325                   1284.8              1236.500000
# 7326                   1263.6              1274.600000
# 7327                   1113.4              1220.600000
# 7328                   1317.7              1231.566667
#
#       avg_yield_soya_beans_5y  avg_yield_sugar_beet_1y  \
# 7309                      NaN                      NaN
# 7310                      NaN                      NaN
# 7311                      NaN                      NaN
# 7312                      NaN                      NaN
# 7313                      NaN                      NaN
# 7314                   939.10                      NaN
# 7315                   969.62                      NaN
# 7316                  1010.14                      NaN
# 7317                   969.38                      NaN
# 7318                   987.80                      NaN
# 7319                  1017.00                      NaN
# 7320                  1001.44                      NaN
# 7321                   969.92                      NaN
# 7322                  1047.34                      NaN
# 7323                  1058.46                      NaN
# 7324                  1110.02                      NaN
# 7325                  1177.02                      NaN
# 7326                  1219.34                      NaN
# 7327                  1217.30                      NaN
# 7328                  1250.98                      NaN
#
#       avg_yield_sugar_beet_3y  avg_yield_sugar_beet_5y  \
# 7309                      NaN                      NaN
# 7310                      NaN                      NaN
# 7311                      NaN                      NaN
# 7312                      NaN                      NaN
# 7313                      NaN                      NaN
# 7314                      NaN                      NaN
# 7315                      NaN                      NaN
# 7316                      NaN                      NaN
# 7317                      NaN                      NaN
# 7318                      NaN                      NaN
# 7319                      NaN                      NaN
# 7320                      NaN                      NaN
# 7321                      NaN                      NaN
# 7322                      NaN                      NaN
# 7323                      NaN                      NaN
# 7324                      NaN                      NaN
# 7325                      NaN                      NaN
# 7326                      NaN                      NaN
# 7327                      NaN                      NaN
# 7328                      NaN                      NaN
#
#       avg_yield_watermelons_1y  avg_yield_watermelons_3y  \
# 7309                       NaN                       NaN
# 7310                    9966.7                       NaN
# 7311                   10347.6                       NaN
# 7312                   11568.0              10627.433333
# 7313                   11581.3              11165.633333
# 7314                   10775.0              11308.100000
# 7315                   11831.3              11395.866667
# 7316                   12126.8              11577.700000
# 7317                   12721.2              12226.433333
# 7318                   12373.2              12407.066667
# 7319                   13367.0              12820.466667
# 7320                   15013.0              13584.400000
# 7321                   15123.1              14501.033333
# 7322                   15020.0              15052.033333
# 7323                   16079.6              15407.566667
# 7324                   15604.8              15568.133333
# 7325                   14293.6              15326.000000
# 7326                   14339.6              14746.000000
# 7327                   14415.1              14349.433333
# 7328                   14490.6              14415.100000
#
#       avg_yield_watermelons_5y  avg_yield_cucumbers_and_gherkins_1y  \
# 7309                       NaN                                  NaN
# 7310                       NaN                               7000.0
# 7311                       NaN                               7000.0
# 7312                       NaN                               7000.0
# 7313                       NaN                               7096.2
# 7314                  10847.72                               7092.6
# 7315                  11220.64                               7107.1
# 7316                  11576.48                               7206.9
# 7317                  11807.12                               7200.0
# 7318                  11965.50                               7290.3
# 7319                  12483.90                               7312.5
# 7320                  13120.24                               9134.2
# 7321                  13719.50                               7516.0
# 7322                  14179.26                               7021.2
# 7323                  14920.54                               7635.6
# 7324                  15368.10                               7183.2
# 7325                  15224.22                               7856.4
# 7326                  15067.52                               7547.2
# 7327                  14946.54                               7547.2
# 7328                  14628.74                               7649.3
#
#       avg_yield_cucumbers_and_gherkins_3y  \
# 7309                                  NaN
# 7310                                  NaN
# 7311                                  NaN
# 7312                          7000.000000
# 7313                          7032.066667
# 7314                          7062.933333
# 7315                          7098.633333
# 7316                          7135.533333
# 7317                          7171.333333
# 7318                          7232.400000
# 7319                          7267.600000
# 7320                          7912.333333
# 7321                          7987.566667
# 7322                          7890.466667
# 7323                          7390.933333
# 7324                          7280.000000
# 7325                          7558.400000
# 7326                          7528.933333
# 7327                          7650.266667
# 7328                          7581.233333
#
#       avg_yield_cucumbers_and_gherkins_5y  avg_yield_tomatoes_1y  \
# 7309                                  NaN                    NaN
# 7310                                  NaN                 3223.2
# 7311                                  NaN                 3708.3
# 7312                                  NaN                 3869.6
# 7313                                  NaN                 4081.5
# 7314                              7037.76                 5231.1
# 7315                              7059.18                 7387.4
# 7316                              7100.56                 4198.5
# 7317                              7140.56                 4502.7
# 7318                              7179.38                 4818.0
# 7319                              7223.36                 4069.1
# 7320                              7628.78                 9594.7
# 7321                              7690.60                 7373.8
# 7322                              7654.84                 8655.1
# 7323                              7723.90                11372.1
# 7324                              7698.04                 7828.6
# 7325                              7442.48                11355.1
# 7326                              7448.72                 9998.3
# 7327                              7553.92                10000.0
# 7328                              7556.66                10000.0
#
#       avg_yield_tomatoes_3y  avg_yield_tomatoes_5y  avg_yield_bananas_1y  \
# 7309                    NaN                    NaN                   NaN
# 7310                    NaN                    NaN                9600.0
# 7311                    NaN                    NaN                9600.0
# 7312            3600.366667                    NaN                9600.0
# 7313            3886.466667                    NaN               10000.0
# 7314            4394.066667                4022.74               10400.0
# 7315            5566.666667                4855.58               10400.0
# 7316            5605.666667                4953.62               11200.0
# 7317            5362.866667                5080.24               12000.0
# 7318            4506.400000                5227.54               11600.0
# 7319            4463.266667                4995.14               12000.0
# 7320            6160.600000                5436.60               11923.1
# 7321            7012.533333                6071.66               12307.7
# 7322            8541.200000                6902.14               11923.1
# 7323            9133.666667                8212.96               11769.2
# 7324            9285.266667                8964.86               11884.6
# 7325           10185.266667                9316.94               12153.8
# 7326            9727.333333                9841.84               12278.5
# 7327           10451.133333               10110.82               12340.0
# 7328            9999.433333                9836.40               12353.8
#
#       avg_yield_bananas_3y  avg_yield_bananas_5y  avg_yield_cassava_fresh_1y  \
# 7309                   NaN                   NaN                         NaN
# 7310                   NaN                   NaN                     15317.0
# 7311                   NaN                   NaN                     14144.3
# 7312           9600.000000                   NaN                     12127.7
# 7313           9733.333333                   NaN                     13120.4
# 7314          10000.000000               9840.00                     13184.6
# 7315          10266.666667              10000.00                     14933.0
# 7316          10666.666667              10320.00                     15065.4
# 7317          11200.000000              10800.00                     14255.1
# 7318          11600.000000              11120.00                     15511.5
# 7319          11866.666667              11440.00                     13968.4
# 7320          11841.033333              11744.62                     14748.9
# 7321          12076.933333              11966.16                     14273.9
# 7322          12051.300000              11950.78                     16361.4
# 7323          12000.000000              11984.62                     18655.4
# 7324          11858.966667              11961.54                     14968.8
# 7325          11935.866667              12007.68                     13994.1
# 7326          12105.633333              12001.84                     12664.5
# 7327          12257.433333              12085.22                     14266.1
# 7328          12324.100000              12202.14                     14421.3
#
#       avg_yield_cassava_fresh_3y  avg_yield_cassava_fresh_5y  sum_rain_winter  \
# 7309                         NaN                         NaN              NaN
# 7310                         NaN                         NaN              NaN
# 7311                         NaN                         NaN              NaN
# 7312                13863.000000                         NaN              NaN
# 7313                13130.800000                         NaN              NaN
# 7314                12810.900000                    13578.80              NaN
# 7315                13746.000000                    13502.00              NaN
# 7316                14394.333333                    13686.22              NaN
# 7317                14751.166667                    14111.70              NaN
# 7318                14944.000000                    14589.92              NaN
# 7319                14578.333333                    14746.68              NaN
# 7320                14742.933333                    14709.86              NaN
# 7321                14330.400000                    14551.56            13.22
# 7322                15128.066667                    14972.82            40.41
# 7323                16430.233333                    15601.60            31.93
# 7324                16661.866667                    15801.68            27.90
# 7325                15872.766667                    15650.72            28.80
# 7326                13875.800000                    15328.84             4.51
# 7327                13641.566667                    14909.78            23.74
# 7328                13783.966667                    14062.96            25.88
#
#       sum_rain_spring  sum_rain_summer  sum_rain_autumn  sum_rain_annual  \
# 7309              NaN              NaN              NaN              NaN
# 7310              NaN              NaN              NaN              NaN
# 7311              NaN              NaN              NaN              NaN
# 7312              NaN              NaN              NaN              NaN
# 7313              NaN              NaN              NaN              NaN
# 7314              NaN              NaN              NaN              NaN
# 7315              NaN              NaN              NaN              NaN
# 7316              NaN              NaN              NaN              NaN
# 7317              NaN              NaN              NaN              NaN
# 7318              NaN              NaN              NaN              NaN
# 7319              NaN              NaN              NaN              NaN
# 7320              NaN              NaN              NaN              NaN
# 7321           277.48           495.59           329.27          1115.56
# 7322           147.26           420.47           428.45          1036.59
# 7323           152.61           528.89           397.50          1110.93
# 7324           180.03           445.40           309.94           963.27
# 7325           251.81           368.31           381.85          1030.77
# 7326           263.40           391.18           247.09           906.18
# 7327           273.39           426.22           477.84          1201.19
# 7328           380.68           454.56           353.96          1215.08
#
#       avg_solar_winter  avg_solar_spring  avg_solar_summer  avg_solar_autumn  \
# 7309               NaN               NaN               NaN               NaN
# 7310               NaN               NaN               NaN               NaN
# 7311               NaN               NaN               NaN               NaN
# 7312               NaN               NaN               NaN               NaN
# 7313               NaN               NaN               NaN               NaN
# 7314               NaN               NaN               NaN               NaN
# 7315               NaN               NaN               NaN               NaN
# 7316               NaN               NaN               NaN               NaN
# 7317               NaN               NaN               NaN               NaN
# 7318               NaN               NaN               NaN               NaN
# 7319               NaN               NaN               NaN               NaN
# 7320               NaN               NaN               NaN               NaN
# 7321               NaN               NaN               NaN               NaN
# 7322               NaN               NaN               NaN               NaN
# 7323               NaN               NaN               NaN               NaN
# 7324         19.080000         22.120000         19.033333         18.316667
# 7325         20.763333         23.440000         20.113333         18.540000
# 7326         20.196667         24.043333         20.926667         20.233333
# 7327         20.223333         22.436667         20.183333         17.926667
# 7328         19.963333         22.226667         19.790000         18.816667
#
#       avg_solar_annual  avg_temp_winter  avg_temp_spring  avg_temp_summer  \
# 7309               NaN              NaN              NaN              NaN
# 7310               NaN              NaN              NaN              NaN
# 7311               NaN              NaN              NaN              NaN
# 7312               NaN              NaN              NaN              NaN
# 7313               NaN              NaN              NaN              NaN
# 7314               NaN              NaN              NaN              NaN
# 7315               NaN              NaN              NaN              NaN
# 7316               NaN              NaN              NaN              NaN
# 7317               NaN              NaN              NaN              NaN
# 7318               NaN              NaN              NaN              NaN
# 7319               NaN              NaN              NaN              NaN
# 7320               NaN              NaN              NaN              NaN
# 7321               NaN        22.730000        28.180000        25.583333
# 7322               NaN        23.150000        30.103333        26.676667
# 7323               NaN        22.856667        30.083333        26.510000
# 7324         19.637500        23.693333        28.200000        26.096667
# 7325         20.714167        24.686667        28.986667        25.663333
# 7326         21.350000        24.076667        28.260000        26.143333
# 7327         20.192500        23.413333        28.596667        26.873333
# 7328         20.199167        24.246667        28.456667        26.090000
#
#       avg_temp_autumn  avg_temp_annual  pesticides_lag1  fertilizer_lag1  \
# 7309              NaN              NaN              NaN              NaN
# 7310              NaN              NaN              NaN         6.588943
# 7311              NaN              NaN              NaN        10.308020
# 7312              NaN              NaN              NaN        12.159696
# 7313              NaN              NaN              NaN        10.789281
# 7314              NaN              NaN              NaN        13.756906
# 7315              NaN              NaN              NaN        12.090537
# 7316              NaN              NaN              NaN        15.635716
# 7317              NaN              NaN              NaN        17.250999
# 7318              NaN              NaN              NaN        17.873107
# 7319              NaN              NaN              NaN        17.742262
# 7320              NaN              NaN              NaN        16.659945
# 7321        24.303333        25.199167              NaN        18.580125
# 7322        24.500000        26.107500              NaN        18.704576
# 7323        23.630000        25.770000              NaN        27.797375
# 7324        24.600000        25.647500              NaN        25.613470
# 7325        24.623333        25.990000              NaN        25.354604
# 7326        25.056667        25.884167              NaN        31.555306
# 7327        25.066667        25.987500              NaN        35.131065
# 7328        23.866667        25.665000              NaN        43.465309
#
#       latitude  longitude
# 7309     15.87     100.99
# 7310     15.87     100.99
# 7311     15.87     100.99
# 7312     15.87     100.99
# 7313     15.87     100.99
# 7314     15.87     100.99
# 7315     15.87     100.99
# 7316     15.87     100.99
# 7317     15.87     100.99
# 7318     15.87     100.99
# 7319     15.87     100.99
# 7320     15.87     100.99
# 7321     15.87     100.99
# 7322     15.87     100.99
# 7323     15.87     100.99
# 7324     15.87     100.99
# 7325     15.87     100.99
# 7326     15.87     100.99
# 7327     15.87     100.99
# 7328     15.87     100.99

# %%
# Filter data to relevant years (1983 onwards)
x_features = x_features[x_features['year'] >= 1982]

# Save to Parquet
x_features.to_parquet('Parquet/x_features_v2.parquet')

# Output shape for verification
print(f"Final X features shape: {x_features.shape}")

x_features.head()
# Out:
# Final X features shape: (6631, 66)
#     year         area  avg_yield_maize_corn_1y  avg_yield_maize_corn_3y  \
# 12  1982  Afghanistan                   1669.0              1650.100000
# 13  1983  Afghanistan                   1665.8              1668.633333
# 14  1984  Afghanistan                   1664.1              1666.300000
# 15  1985  Afghanistan                   1661.2              1663.700000
# 16  1986  Afghanistan                   1665.2              1663.500000
#
#     avg_yield_maize_corn_5y  avg_yield_other_vegetables_fresh_nec_1y  \
# 12                  1630.38                                   6892.2
# 13                  1646.88                                   6919.2
# 14                  1656.04                                   7065.7
# 15                  1666.24                                   7155.1
# 16                  1665.06                                   7145.9
#
#     avg_yield_other_vegetables_fresh_nec_3y  \
# 12                              6748.933333
# 13                              6846.166667
# 14                              6959.033333
# 15                              7046.666667
# 16                              7122.233333
#
#     avg_yield_other_vegetables_fresh_nec_5y  avg_yield_potatoes_1y  \
# 12                                  6489.62                15423.7
# 13                                  6717.30                15511.4
# 14                                  6846.34                15764.7
# 15                                  6951.86                14444.4
# 16                                  7035.62                14090.9
#
#     avg_yield_potatoes_3y  avg_yield_potatoes_5y  avg_yield_rice_1y  \
# 12           14880.500000               13780.82             2241.4
# 13           15265.133333               14777.84             2199.4
# 14           15566.600000               15183.52             2258.1
# 15           15240.166667               15200.90             2241.6
# 16           14766.666667               15047.02             2248.2
#
#     avg_yield_rice_3y  avg_yield_rice_5y  avg_yield_sugar_cane_1y  \
# 12        2181.766667            2097.64                  18918.9
# 13        2204.533333            2156.56                  19090.9
# 14        2232.966667            2200.56                  19375.0
# 15        2233.033333            2222.66                  19354.8
# 16        2249.300000            2237.74                  19333.3
#
#     avg_yield_sugar_cane_3y  avg_yield_sugar_cane_5y  avg_yield_wheat_1y  \
# 12             18378.366667                 17427.02              1235.0
# 13             18976.233333                 18045.20              1229.9
# 14             19128.266667                 18720.20              1258.0
# 15             19273.566667                 19131.70              1231.9
# 16             19354.366667                 19214.58              1227.7
#
#     avg_yield_wheat_3y  avg_yield_wheat_5y  avg_yield_oil_palm_fruit_1y  \
# 12         1240.533333             1210.10                          NaN
# 13         1239.933333             1229.90                          NaN
# 14         1240.966667             1241.90                          NaN
# 15         1239.933333             1241.94                          NaN
# 16         1239.200000             1236.50                          NaN
#
#     avg_yield_oil_palm_fruit_3y  avg_yield_oil_palm_fruit_5y  \
# 12                          NaN                          NaN
# 13                          NaN                          NaN
# 14                          NaN                          NaN
# 15                          NaN                          NaN
# 16                          NaN                          NaN
#
#     avg_yield_barley_1y  avg_yield_barley_3y  avg_yield_barley_5y  \
# 12               1079.1          1058.066667              1038.06
# 13               1073.9          1067.333333              1059.30
# 14               1099.2          1084.066667              1069.46
# 15               1085.5          1086.200000              1077.34
# 16               1086.0          1090.233333              1084.74
#
#     avg_yield_soya_beans_1y  avg_yield_soya_beans_3y  avg_yield_soya_beans_5y  \
# 12                      NaN                      NaN                      NaN
# 13                      NaN                      NaN                      NaN
# 14                      NaN                      NaN                      NaN
# 15                      NaN                      NaN                      NaN
# 16                      NaN                      NaN                      NaN
#
#     avg_yield_sugar_beet_1y  avg_yield_sugar_beet_3y  avg_yield_sugar_beet_5y  \
# 12                   8333.3             17361.100000                 17216.66
# 13                   9090.9             13099.733333                 15154.84
# 14                  20000.0             12474.733333                 16234.84
# 15                  20000.0             16363.633333                 15859.84
# 16                   3333.3             14444.433333                 12151.50
#
#     avg_yield_watermelons_1y  avg_yield_watermelons_3y  \
# 12                    9538.5               9187.533333
# 13                    9457.9               9388.200000
# 14                    9754.9               9583.766667
# 15                    9630.0               9614.266667
# 16                    9556.7               9647.200000
#
#     avg_yield_watermelons_5y  avg_yield_cucumbers_and_gherkins_1y  \
# 12                   8695.38                                  NaN
# 13                   9127.32                                  NaN
# 14                   9355.08                                  NaN
# 15                   9509.90                                  NaN
# 16                   9587.60                                  NaN
#
#     avg_yield_cucumbers_and_gherkins_3y  avg_yield_cucumbers_and_gherkins_5y  \
# 12                                  NaN                                  NaN
# 13                                  NaN                                  NaN
# 14                                  NaN                                  NaN
# 15                                  NaN                                  NaN
# 16                                  NaN                                  NaN
#
#     avg_yield_tomatoes_1y  avg_yield_tomatoes_3y  avg_yield_tomatoes_5y  \
# 12                    NaN                    NaN                    NaN
# 13                    NaN                    NaN                    NaN
# 14                    NaN                    NaN                    NaN
# 15                    NaN                    NaN                    NaN
# 16                    NaN                    NaN                    NaN
#
#     avg_yield_bananas_1y  avg_yield_bananas_3y  avg_yield_bananas_5y  \
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
# 15                   NaN                   NaN                   NaN
# 16                   NaN                   NaN                   NaN
#
#     avg_yield_cassava_fresh_1y  avg_yield_cassava_fresh_3y  \
# 12                         NaN                         NaN
# 13                         NaN                         NaN
# 14                         NaN                         NaN
# 15                         NaN                         NaN
# 16                         NaN                         NaN
#
#     avg_yield_cassava_fresh_5y  sum_rain_winter  sum_rain_spring  \
# 12                         NaN           150.63           113.69
# 13                         NaN           139.74           172.94
# 14                         NaN            60.60           202.73
# 15                         NaN            68.62            89.17
# 16                         NaN            75.65            65.67
#
#     sum_rain_summer  sum_rain_autumn  sum_rain_annual  avg_solar_winter  \
# 12            34.44            26.56           325.32               NaN
# 13             3.65            57.21           373.54               NaN
# 14             9.34             0.58           273.25               NaN
# 15            17.24            21.07           196.10         11.200000
# 16             5.44             8.33           155.09         11.366667
#
#     avg_solar_spring  avg_solar_summer  avg_solar_autumn  avg_solar_annual  \
# 12               NaN               NaN               NaN               NaN
# 13               NaN               NaN               NaN               NaN
# 14               NaN               NaN               NaN               NaN
# 15         21.623333         26.856667         17.183333         19.215833
# 16         20.270000         26.086667         17.243333         18.741667
#
#     avg_temp_winter  avg_temp_spring  avg_temp_summer  avg_temp_autumn  \
# 12         0.880000        12.286667        21.830000        11.800000
# 13        -0.713333         9.976667        21.856667        11.483333
# 14         0.953333         9.246667        22.393333        12.940000
# 15        -1.406667        13.023333        24.120000        11.816667
# 16         1.843333        12.990000        22.946667        12.266667
#
#     avg_temp_annual  pesticides_lag1  fertilizer_lag1  latitude  longitude
# 12        11.699167              NaN         5.778887     34.53      69.17
# 13        10.650833              NaN         6.672946     34.53      69.17
# 14        11.383333              NaN         7.152971     34.53      69.17
# 15        11.888333              NaN         9.178255     34.53      69.17
# 16        12.511667              NaN         9.224020     34.53      69.17
