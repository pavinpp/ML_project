# %%
import pandas as pd
import numpy as np

# %%
xy = pd.read_parquet('XY_version1.parquet')
xy.head()
# Out:
#    year         area  avg_yield_maize_corn_1y  avg_yield_maize_corn_3y  \
# 0  1983  Afghanistan                   1665.8              1668.633333
# 1  1984  Afghanistan                   1664.1              1666.300000
# 2  1985  Afghanistan                   1661.2              1663.700000
# 3  1986  Afghanistan                   1665.2              1663.500000
# 4  1987  Afghanistan                   1687.5              1671.300000
#
#    avg_yield_maize_corn_6y  avg_yield_other_vegetables_fresh_nec_1y  \
# 0              1636.283333                                   6919.2
# 1              1649.750000                                   7065.7
# 2              1656.900000                                   7155.1
# 3              1666.066667                                   7145.9
# 4              1668.800000                                   7249.5
#
#    avg_yield_other_vegetables_fresh_nec_3y  \
# 0                              6846.166667
# 1                              6959.033333
# 2                              7046.666667
# 3                              7122.233333
# 4                              7183.500000
#
#    avg_yield_other_vegetables_fresh_nec_6y  avg_yield_potatoes_1y  \
# 0                              6561.216667                15511.4
# 1                              6775.366667                15764.7
# 2                              6897.800000                14444.4
# 3                              6984.200000                14090.9
# 4                              7071.266667                15866.7
#
#    avg_yield_potatoes_3y  ...  Y_oil_palm_fruit  Y_other_vegetables_fresh_nec  \
# 0           15265.133333  ...               NaN                        7065.7
# 1           15566.600000  ...               NaN                        7155.1
# 2           15240.166667  ...               NaN                        7145.9
# 3           14766.666667  ...               NaN                        7249.5
# 4           14800.666667  ...               NaN                        7524.8
#
#    Y_potatoes  Y_rice  Y_soya_beans  Y_sugar_beet  Y_sugar_cane  Y_tomatoes  \
# 0     15764.7  2258.1           NaN       20000.0       19375.0         NaN
# 1     14444.4  2241.6           NaN       20000.0       19354.8         NaN
# 2     14090.9  2248.2           NaN        3333.3       19333.3         NaN
# 3     15866.7  2240.0           NaN       12500.0       20000.0         NaN
# 4     15500.0  2000.0           NaN       15000.0       20000.0         NaN
#
#    Y_watermelons  Y_wheat
# 0         9754.9   1258.0
# 1         9630.0   1231.9
# 2         9556.7   1227.7
# 3        10058.8   1189.0
# 4         9952.9   1284.9
#
# [5 rows x 118 columns]

# %%
latlong  = pd.read_csv('coordinates_countries_full_209.csv')
latlong['area'] = latlong['Area'].str.replace(' ', '_')
latlong = latlong[['area', 'latitude', 'longitude']]

# %%
xy = xy.merge(latlong, on='area')
xy = pd.get_dummies(xy, columns=['area'])
xy.columns = (
    xy.columns
    .str.strip()             # remove leading/trailing spaces
    .str.replace(' ', '_')   # replace spaces
    .str.replace(r'[^A-Za-z0-9_]', '', regex=True)  # remove special chars
)
xy.head()
# Out:
#    year  avg_yield_maize_corn_1y  avg_yield_maize_corn_3y  \
# 0  1983                   1665.8              1668.633333
# 1  1984                   1664.1              1666.300000
# 2  1985                   1661.2              1663.700000
# 3  1986                   1665.2              1663.500000
# 4  1987                   1687.5              1671.300000
#
#    avg_yield_maize_corn_6y  avg_yield_other_vegetables_fresh_nec_1y  \
# 0              1636.283333                                   6919.2
# 1              1649.750000                                   7065.7
# 2              1656.900000                                   7155.1
# 3              1666.066667                                   7145.9
# 4              1668.800000                                   7249.5
#
#    avg_yield_other_vegetables_fresh_nec_3y  \
# 0                              6846.166667
# 1                              6959.033333
# 2                              7046.666667
# 3                              7122.233333
# 4                              7183.500000
#
#    avg_yield_other_vegetables_fresh_nec_6y  avg_yield_potatoes_1y  \
# 0                              6561.216667                15511.4
# 1                              6775.366667                15764.7
# 2                              6897.800000                14444.4
# 3                              6984.200000                14090.9
# 4                              7071.266667                15866.7
#
#    avg_yield_potatoes_3y  avg_yield_potatoes_6y  ...  \
# 0           15265.133333           14069.250000  ...
# 1           15566.600000           14942.316667  ...
# 2           15240.166667           15060.333333  ...
# 3           14766.666667           15015.900000  ...
# 4           14800.666667           15183.633333  ...
#
#    area_United_States_of_America  area_Uruguay  area_Uzbekistan  area_Vanuatu  \
# 0                          False         False            False         False
# 1                          False         False            False         False
# 2                          False         False            False         False
# 3                          False         False            False         False
# 4                          False         False            False         False
#
#    area_Venezuela_Bolivarian_Republic_of  area_Viet_Nam  area_Yemen  \
# 0                                  False          False       False
# 1                                  False          False       False
# 2                                  False          False       False
# 3                                  False          False       False
# 4                                  False          False       False
#
#    area_Yugoslav_SFR  area_Zambia  area_Zimbabwe
# 0              False        False          False
# 1              False        False          False
# 2              False        False          False
# 3              False        False          False
# 4              False        False          False
#
# [5 rows x 294 columns]

# %%
xy.columns.tolist()
# Out:
# ['year',
#  'avg_yield_maize_corn_1y',
#  'avg_yield_maize_corn_3y',
#  'avg_yield_maize_corn_6y',
#  'avg_yield_other_vegetables_fresh_nec_1y',
#  'avg_yield_other_vegetables_fresh_nec_3y',
#  'avg_yield_other_vegetables_fresh_nec_6y',
#  'avg_yield_potatoes_1y',
#  'avg_yield_potatoes_3y',
#  'avg_yield_potatoes_6y',
#  'avg_yield_rice_1y',
#  'avg_yield_rice_3y',
#  'avg_yield_rice_6y',
#  'avg_yield_sugar_cane_1y',
#  'avg_yield_sugar_cane_3y',
#  'avg_yield_sugar_cane_6y',
#  'avg_yield_wheat_1y',
#  'avg_yield_wheat_3y',
#  'avg_yield_wheat_6y',
#  'avg_yield_oil_palm_fruit_1y',
#  'avg_yield_oil_palm_fruit_3y',
#  'avg_yield_oil_palm_fruit_6y',
#  'avg_yield_barley_1y',
#  'avg_yield_barley_3y',
#  'avg_yield_barley_6y',
#  'avg_yield_soya_beans_1y',
#  'avg_yield_soya_beans_3y',
#  'avg_yield_soya_beans_6y',
#  'avg_yield_sugar_beet_1y',
#  'avg_yield_sugar_beet_3y',
#  'avg_yield_sugar_beet_6y',
#  'avg_yield_watermelons_1y',
#  'avg_yield_watermelons_3y',
#  'avg_yield_watermelons_6y',
#  'avg_yield_cucumbers_and_gherkins_1y',
#  'avg_yield_cucumbers_and_gherkins_3y',
#  'avg_yield_cucumbers_and_gherkins_6y',
#  'avg_yield_tomatoes_1y',
#  'avg_yield_tomatoes_3y',
#  'avg_yield_tomatoes_6y',
#  'avg_yield_bananas_1y',
#  'avg_yield_bananas_3y',
#  'avg_yield_bananas_6y',
#  'avg_yield_cassava_fresh_1y',
#  'avg_yield_cassava_fresh_3y',
#  'avg_yield_cassava_fresh_6y',
#  'rain_Jan',
#  'rain_Feb',
#  'rain_Mar',
#  'rain_Apr',
#  'rain_May',
#  'rain_Jun',
#  'rain_Jul',
#  'rain_Aug',
#  'rain_Sep',
#  'rain_Oct',
#  'rain_Nov',
#  'rain_Dec',
#  'avg_rain_1_3',
#  'avg_rain_3_6',
#  'avg_rain_6_9',
#  'avg_rain_10_12',
#  'avg_rain_1_12',
#  'solar_Jan',
#  'solar_Feb',
#  'solar_Mar',
#  'solar_Apr',
#  'solar_May',
#  'solar_Jun',
#  'solar_Jul',
#  'solar_Aug',
#  'solar_Sep',
#  'solar_Oct',
#  'solar_Nov',
#  'solar_Dec',
#  'avg_solar_1_3',
#  'avg_solar_3_6',
#  'avg_solar_6_9',
#  'avg_solar_10_12',
#  'avg_solar_1_12',
#  'temp_Jan',
#  'temp_Feb',
#  'temp_Mar',
#  'temp_Apr',
#  'temp_May',
#  'temp_Jun',
#  'temp_Jul',
#  'temp_Aug',
#  'temp_Sep',
#  'temp_Oct',
#  'temp_Nov',
#  'temp_Dec',
#  'avg_temp_1_3',
#  'avg_temp_3_6',
#  'avg_temp_6_9',
#  'avg_temp_10_12',
#  'avg_temp_1_12',
#  'sum_rain_1_3',
#  'sum_rain_3_6',
#  'sum_rain_6_9',
#  'sum_rain_10_12',
#  'sum_rain_1_12',
#  'Y_bananas',
#  'Y_barley',
#  'Y_cassava_fresh',
#  'Y_cucumbers_and_gherkins',
#  'Y_maize_corn',
#  'Y_oil_palm_fruit',
#  'Y_other_vegetables_fresh_nec',
#  'Y_potatoes',
#  'Y_rice',
#  'Y_soya_beans',
#  'Y_sugar_beet',
#  'Y_sugar_cane',
#  'Y_tomatoes',
#  'Y_watermelons',
#  'Y_wheat',
#  'latitude',
#  'longitude',
#  'area_Afghanistan',
#  'area_Albania',
#  'area_Algeria',
#  'area_Angola',
#  'area_Antigua_and_Barbuda',
#  'area_Argentina',
#  'area_Armenia',
#  'area_Australia',
#  'area_Austria',
#  'area_Azerbaijan',
#  'area_Bahamas',
#  'area_Bangladesh',
#  'area_Barbados',
#  'area_Belarus',
#  'area_Belgium',
#  'area_BelgiumLuxembourg',
#  'area_Belize',
#  'area_Benin',
#  'area_Bhutan',
#  'area_Bolivia_Plurinational_State_of',
#  'area_Bosnia_and_Herzegovina',
#  'area_Botswana',
#  'area_Brazil',
#  'area_Bulgaria',
#  'area_Burkina_Faso',
#  'area_Burundi',
#  'area_Cabo_Verde',
#  'area_Cambodia',
#  'area_Cameroon',
#  'area_Canada',
#  'area_Central_African_Republic',
#  'area_Chad',
#  'area_Chile',
#  'area_China',
#  'area_China_Taiwan_Province_of',
#  'area_China_mainland',
#  'area_Colombia',
#  'area_Comoros',
#  'area_Congo',
#  'area_Costa_Rica',
#  'area_Croatia',
#  'area_Cuba',
#  'area_Czechia',
#  'area_Czechoslovakia',
#  'area_Cte_dIvoire',
#  'area_Democratic_Peoples_Republic_of_Korea',
#  'area_Democratic_Republic_of_the_Congo',
#  'area_Denmark',
#  'area_Djibouti',
#  'area_Dominica',
#  'area_Dominican_Republic',
#  'area_Ecuador',
#  'area_Egypt',
#  'area_El_Salvador',
#  'area_Eritrea',
#  'area_Eswatini',
#  'area_Ethiopia',
#  'area_Ethiopia_PDR',
#  'area_Fiji',
#  'area_France',
#  'area_French_Guiana',
#  'area_Gabon',
#  'area_Gambia',
#  'area_Georgia',
#  'area_Germany',
#  'area_Ghana',
#  'area_Greece',
#  'area_Grenada',
#  'area_Guatemala',
#  'area_Guinea',
#  'area_GuineaBissau',
#  'area_Guyana',
#  'area_Haiti',
#  'area_Honduras',
#  'area_Hungary',
#  'area_India',
#  'area_Indonesia',
#  'area_Iran_Islamic_Republic_of',
#  'area_Iraq',
#  'area_Israel',
#  'area_Italy',
#  'area_Jamaica',
#  'area_Japan',
#  'area_Jordan',
#  'area_Kazakhstan',
#  'area_Kenya',
#  'area_Kuwait',
#  'area_Kyrgyzstan',
#  'area_Lao_Peoples_Democratic_Republic',
#  'area_Lebanon',
#  'area_Lesotho',
#  'area_Libya',
#  'area_Lithuania',
#  'area_Luxembourg',
#  'area_Madagascar',
#  'area_Malawi',
#  'area_Malaysia',
#  'area_Maldives',
#  'area_Mali',
#  'area_Mauritania',
#  'area_Mauritius',
#  'area_Mexico',
#  'area_Micronesia_Federated_States_of',
#  'area_Montenegro',
#  'area_Morocco',
#  'area_Mozambique',
#  'area_Myanmar',
#  'area_Namibia',
#  'area_Nepal',
#  'area_Netherlands_Kingdom_of_the',
#  'area_New_Caledonia',
#  'area_New_Zealand',
#  'area_Nicaragua',
#  'area_Niger',
#  'area_Nigeria',
#  'area_North_Macedonia',
#  'area_Oman',
#  'area_Pakistan',
#  'area_Panama',
#  'area_Papua_New_Guinea',
#  'area_Paraguay',
#  'area_Peru',
#  'area_Philippines',
#  'area_Poland',
#  'area_Portugal',
#  'area_Puerto_Rico',
#  'area_Qatar',
#  'area_Republic_of_Korea',
#  'area_Republic_of_Moldova',
#  'area_Romania',
#  'area_Russian_Federation',
#  'area_Rwanda',
#  'area_Runion',
#  'area_Saint_Vincent_and_the_Grenadines',
#  'area_Sao_Tome_and_Principe',
#  'area_Saudi_Arabia',
#  'area_Senegal',
#  'area_Serbia',
#  'area_Serbia_and_Montenegro',
#  'area_Sierra_Leone',
#  'area_Slovakia',
#  'area_Slovenia',
#  'area_Somalia',
#  'area_South_Africa',
#  'area_South_Sudan',
#  'area_Spain',
#  'area_Sri_Lanka',
#  'area_Sudan',
#  'area_Sudan_former',
#  'area_Suriname',
#  'area_Sweden',
#  'area_Switzerland',
#  'area_Syrian_Arab_Republic',
#  'area_Tajikistan',
#  'area_Thailand',
#  'area_TimorLeste',
#  'area_Togo',
#  'area_Trinidad_and_Tobago',
#  'area_Turkmenistan',
#  'area_Trkiye',
#  'area_USSR',
#  'area_Uganda',
#  'area_Ukraine',
#  'area_United_Arab_Emirates',
#  'area_United_Republic_of_Tanzania',
#  'area_United_States_of_America',
#  'area_Uruguay',
#  'area_Uzbekistan',
#  'area_Vanuatu',
#  'area_Venezuela_Bolivarian_Republic_of',
#  'area_Viet_Nam',
#  'area_Yemen',
#  'area_Yugoslav_SFR',
#  'area_Zambia',
#  'area_Zimbabwe']

# %%
features_col =[
 'avg_yield_maize_corn_1y',
 'avg_yield_maize_corn_3y',
 'avg_yield_maize_corn_6y',
 'avg_yield_other_vegetables_fresh_nec_1y',
 'avg_yield_other_vegetables_fresh_nec_3y',
 'avg_yield_other_vegetables_fresh_nec_6y',
 'avg_yield_potatoes_1y',
 'avg_yield_potatoes_3y',
 'avg_yield_potatoes_6y',
 'avg_yield_rice_1y',
 'avg_yield_rice_3y',
 'avg_yield_rice_6y',
 'avg_yield_sugar_cane_1y',
 'avg_yield_sugar_cane_3y',
 'avg_yield_sugar_cane_6y',
 'avg_yield_wheat_1y',
 'avg_yield_wheat_3y',
 'avg_yield_wheat_6y',
 'avg_yield_oil_palm_fruit_1y',
 'avg_yield_oil_palm_fruit_3y',
 'avg_yield_oil_palm_fruit_6y',
 'avg_yield_barley_1y',
 'avg_yield_barley_3y',
 'avg_yield_barley_6y',
 'avg_yield_soya_beans_1y',
 'avg_yield_soya_beans_3y',
 'avg_yield_soya_beans_6y',
 'avg_yield_sugar_beet_1y',
 'avg_yield_sugar_beet_3y',
 'avg_yield_sugar_beet_6y',
 'avg_yield_watermelons_1y',
 'avg_yield_watermelons_3y',
 'avg_yield_watermelons_6y',
 'avg_yield_cucumbers_and_gherkins_1y',
 'avg_yield_cucumbers_and_gherkins_3y',
 'avg_yield_cucumbers_and_gherkins_6y',
 'avg_yield_tomatoes_1y',
 'avg_yield_tomatoes_3y',
 'avg_yield_tomatoes_6y',
 'avg_yield_bananas_1y',
 'avg_yield_bananas_3y',
 'avg_yield_bananas_6y',
 'avg_yield_cassava_fresh_1y',
 'avg_yield_cassava_fresh_3y',
 'avg_yield_cassava_fresh_6y',
 'rain_Jan',
 'rain_Feb',
 'rain_Mar',
 'rain_Apr',
 'rain_May',
 'rain_Jun',
 'rain_Jul',
 'rain_Aug',
 'rain_Sep',
 'rain_Oct',
 'rain_Nov',
 'rain_Dec',
 'avg_rain_1_3',
 'avg_rain_3_6',
 'avg_rain_6_9',
 'avg_rain_10_12',
 'avg_rain_1_12',
 'solar_Jan',
 'solar_Feb',
 'solar_Mar',
 'solar_Apr',
 'solar_May',
 'solar_Jun',
 'solar_Jul',
 'solar_Aug',
 'solar_Sep',
 'solar_Oct',
 'solar_Nov',
 'solar_Dec',
 'avg_solar_1_3',
 'avg_solar_3_6',
 'avg_solar_6_9',
 'avg_solar_10_12',
 'avg_solar_1_12',
 'temp_Jan',
 'temp_Feb',
 'temp_Mar',
 'temp_Apr',
 'temp_May',
 'temp_Jun',
 'temp_Jul',
 'temp_Aug',
 'temp_Sep',
 'temp_Oct',
 'temp_Nov',
 'temp_Dec',
 'avg_temp_1_3',
 'avg_temp_3_6',
 'avg_temp_6_9',
 'avg_temp_10_12',
 'avg_temp_1_12',
 'sum_rain_1_3',
 'sum_rain_3_6',
 'sum_rain_6_9',
 'sum_rain_10_12',
 'sum_rain_1_12',

 'latitude',
 'longitude',
 'area_Afghanistan',
 'area_Albania',
 'area_Algeria',
 'area_Angola',
 'area_Antigua_and_Barbuda',
 'area_Argentina',
 'area_Armenia',
 'area_Australia',
 'area_Austria',
 'area_Azerbaijan',
 'area_Bahamas',
 'area_Bangladesh',
 'area_Barbados',
 'area_Belarus',
 'area_Belgium',
 'area_BelgiumLuxembourg',
 'area_Belize',
 'area_Benin',
 'area_Bhutan',
 'area_Bolivia_Plurinational_State_of',
 'area_Bosnia_and_Herzegovina',
 'area_Botswana',
 'area_Brazil',
 'area_Bulgaria',
 'area_Burkina_Faso',
 'area_Burundi',
 'area_Cabo_Verde',
 'area_Cambodia',
 'area_Cameroon',
 'area_Canada',
 'area_Central_African_Republic',
 'area_Chad',
 'area_Chile',
 'area_China',
 'area_China_Taiwan_Province_of',
 'area_China_mainland',
 'area_Colombia',
 'area_Comoros',
 'area_Congo',
 'area_Costa_Rica',
 'area_Croatia',
 'area_Cuba',
 'area_Czechia',
 'area_Czechoslovakia',
 'area_Cte_dIvoire',
 'area_Democratic_Peoples_Republic_of_Korea',
 'area_Democratic_Republic_of_the_Congo',
 'area_Denmark',
 'area_Djibouti',
 'area_Dominica',
 'area_Dominican_Republic',
 'area_Ecuador',
 'area_Egypt',
 'area_El_Salvador',
 'area_Eritrea',
 'area_Eswatini',
 'area_Ethiopia',
 'area_Ethiopia_PDR',
 'area_Fiji',
 'area_France',
 'area_French_Guiana',
 'area_Gabon',
 'area_Gambia',
 'area_Georgia',
 'area_Germany',
 'area_Ghana',
 'area_Greece',
 'area_Grenada',
 'area_Guatemala',
 'area_Guinea',
 'area_GuineaBissau',
 'area_Guyana',
 'area_Haiti',
 'area_Honduras',
 'area_Hungary',
 'area_India',
 'area_Indonesia',
 'area_Iran_Islamic_Republic_of',
 'area_Iraq',
 'area_Israel',
 'area_Italy',
 'area_Jamaica',
 'area_Japan',
 'area_Jordan',
 'area_Kazakhstan',
 'area_Kenya',
 'area_Kuwait',
 'area_Kyrgyzstan',
 'area_Lao_Peoples_Democratic_Republic',
 'area_Lebanon',
 'area_Lesotho',
 'area_Libya',
 'area_Lithuania',
 'area_Luxembourg',
 'area_Madagascar',
 'area_Malawi',
 'area_Malaysia',
 'area_Maldives',
 'area_Mali',
 'area_Mauritania',
 'area_Mauritius',
 'area_Mexico',
 'area_Micronesia_Federated_States_of',
 'area_Montenegro',
 'area_Morocco',
 'area_Mozambique',
 'area_Myanmar',
 'area_Namibia',
 'area_Nepal',
 'area_Netherlands_Kingdom_of_the',
 'area_New_Caledonia',
 'area_New_Zealand',
 'area_Nicaragua',
 'area_Niger',
 'area_Nigeria',
 'area_North_Macedonia',
 'area_Oman',
 'area_Pakistan',
 'area_Panama',
 'area_Papua_New_Guinea',
 'area_Paraguay',
 'area_Peru',
 'area_Philippines',
 'area_Poland',
 'area_Portugal',
 'area_Puerto_Rico',
 'area_Qatar',
 'area_Republic_of_Korea',
 'area_Republic_of_Moldova',
 'area_Romania',
 'area_Russian_Federation',
 'area_Rwanda',
 'area_Runion',
 'area_Saint_Vincent_and_the_Grenadines',
 'area_Sao_Tome_and_Principe',
 'area_Saudi_Arabia',
 'area_Senegal',
 'area_Serbia',
 'area_Serbia_and_Montenegro',
 'area_Sierra_Leone',
 'area_Slovakia',
 'area_Slovenia',
 'area_Somalia',
 'area_South_Africa',
 'area_South_Sudan',
 'area_Spain',
 'area_Sri_Lanka',
 'area_Sudan',
 'area_Sudan_former',
 'area_Suriname',
 'area_Sweden',
 'area_Switzerland',
 'area_Syrian_Arab_Republic',
 'area_Tajikistan',
 'area_Thailand',
 'area_TimorLeste',
 'area_Togo',
 'area_Trinidad_and_Tobago',
 'area_Turkmenistan',
 'area_Trkiye',
 'area_USSR',
 'area_Uganda',
 'area_Ukraine',
 'area_United_Arab_Emirates',
 'area_United_Republic_of_Tanzania',
 'area_United_States_of_America',
 'area_Uruguay',
 'area_Uzbekistan',
 'area_Vanuatu',
 'area_Venezuela_Bolivarian_Republic_of',
 'area_Viet_Nam',
 'area_Yemen',
 'area_Yugoslav_SFR',
 'area_Zambia',
 'area_Zimbabwe']

# %% [markdown]
# Start Neural Network Model

# %%
xy_drop_na = xy[xy['Y_rice']>=0]
xy['Y_rice'].hist()
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.pyplot as plt

class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y) + 1e-8)  # small epsilon for stability

# =========================
# 1) Clean data & time splits
# =========================

# Keep only non-negative Y_rice
xy_drop_na = xy[xy["Y_rice"] >= 0].copy()

# Remove inf and NaN in all columns
xy_drop_na = xy_drop_na.replace([np.inf, -np.inf], np.nan).dropna()

# Time-based split
test_xy  = xy_drop_na[xy_drop_na["year"] >= 2019].copy()
train_val_xy = xy_drop_na[xy_drop_na["year"] < 2019].copy()

train_xy = train_val_xy[train_val_xy["year"] < 2014].copy()
val_xy   = train_val_xy[train_val_xy["year"] >= 2014].copy()

print("Rows -> train:", len(train_xy), "val:", len(val_xy), "test:", len(test_xy))

# =========================
# 2) Features / target & scaling
# =========================

target_col = "Y_rice"
# Only drop target; keep 'year' as a feature
non_feature_cols = ["Y_rice"]

feature_cols = [c for c in xy_drop_na.columns if c not in non_feature_cols]
print("Number of features:", len(feature_cols))

X_train_df = train_xy[feature_cols].copy()
y_train_df = train_xy[[target_col]].copy()

X_val_df   = val_xy[feature_cols].copy()
y_val_df   = val_xy[[target_col]].copy()

X_test_df  = test_xy[feature_cols].copy()
y_test_df  = test_xy[[target_col]].copy()

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_df).astype(np.float32)
X_val   = scaler.transform(X_val_df).astype(np.float32)
X_test  = scaler.transform(X_test_df).astype(np.float32)

y_train = y_train_df.to_numpy().astype(np.float32)
y_val   = y_val_df.to_numpy().astype(np.float32)
y_test  = y_test_df.to_numpy().astype(np.float32)

# =========================
# 3) Sanity check for NaN / inf
# =========================

def check_arr(name, arr):
    print(
        f"{name} -> shape: {arr.shape}, "
        f"NaN: {np.isnan(arr).any()}, "
        f"inf: {np.isinf(arr).any()}"
    )

check_arr("X_train", X_train)
check_arr("y_train", y_train)
check_arr("X_val",   X_val)
check_arr("y_val",   y_val)
check_arr("X_test",  X_test)
check_arr("y_test",  y_test)

# If any of those show True for NaN/inf, that's the source of NaN loss.

# =========================
# 4) PyTorch datasets + loaders
# =========================

train_dataset = TensorDataset(torch.FloatTensor(X_train), torch.FloatTensor(y_train))
val_dataset   = TensorDataset(torch.FloatTensor(X_val),  torch.FloatTensor(y_val))

# test has only features (no labels)
test_dataset  = TensorDataset(torch.FloatTensor(X_test))

batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_dataset,  batch_size=batch_size, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# =========================
# 5) Define neural network
# =========================

n_neuron   = 64
N_layers   = 3
activation = "ReLU"
learning_rate = 0.001
num_epochs = 200

layers_list = [nn.Linear(X_train.shape[1], n_neuron),
               getattr(nn, activation)()]

for _ in range(N_layers - 1):
    layers_list.append(nn.Linear(n_neuron, n_neuron))
    layers_list.append(getattr(nn, activation)())

layers_list.append(nn.Linear(n_neuron, 1))  # output layer (Y_rice)

model = nn.Sequential(*layers_list).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.MSELoss()

print(model)

# =========================
# 6) Training loop with early stopping
# =========================

criterion = RMSELoss()     

best_state_dict = model.state_dict()
best_val_loss = float("inf")
patience = 20
patience_counter = 0

train_losses = []
val_losses = []

for epoch in range(num_epochs):
    # ---- Train ----
    model.train()
    running_train_loss = 0.0

    for batch_X, batch_y in train_loader:
        batch_X = batch_X.to(device)
        batch_y = batch_y.to(device)

        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)   # <-- RMSE
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item()

    train_loss = running_train_loss / len(train_loader)

    # ---- Validation ----
    model.eval()
    running_val_loss = 0.0
    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)   # <-- RMSE
            running_val_loss += loss.item()

    val_loss = running_val_loss / len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    print(f"Epoch {epoch+1}/{num_epochs} "
          f"Train RMSE: {train_loss:.4f}, Val RMSE: {val_loss:.4f}")

    # Early Stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict = model.state_dict()
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

model.load_state_dict(best_state_dict)


# =========================
# 7) Plot training history
# =========================

def plot_history(train_losses, val_losses):
    plt.figure(figsize=(8,5))
    plt.plot(train_losses, label="Train loss (MSE)")
    plt.plot(val_losses, label="Val loss (MSE)")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training / Validation Loss History")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

plot_history(train_losses, val_losses)

# =========================
# 8) Predict on test set
# =========================
model.eval()
y_pred_test = []

with torch.no_grad():
    for (batch_X,) in test_loader:      # unpack single-tensor batch
        batch_X = batch_X.to(device)
        preds = model(batch_X).cpu().numpy().flatten()
        y_pred_test.extend(preds)

y_pred_test = np.array(y_pred_test, dtype=np.float32)

# ---- Compute metrics ----
from sklearn.metrics import root_mean_squared_error, r2_score

from sklearn.metrics import root_mean_squared_error, r2_score

rmse = root_mean_squared_error(y_test, y_pred_test)
r2   = r2_score(y_test, y_pred_test)

print("RMSE:", rmse)
print("R²:", r2)
# Out:
# Rows -> train: 116 val: 25 test: 25
# Number of features: 293
# X_train -> shape: (116, 293), NaN: False, inf: False
# y_train -> shape: (116, 1), NaN: False, inf: False
# X_val -> shape: (25, 293), NaN: False, inf: False
# y_val -> shape: (25, 1), NaN: False, inf: False
# X_test -> shape: (25, 293), NaN: False, inf: False
# y_test -> shape: (25, 1), NaN: False, inf: False
# Using device: cpu
# Sequential(
#   (0): Linear(in_features=293, out_features=64, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=64, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=64, out_features=1, bias=True)
# )
# Epoch 1/200 Train RMSE: 5277.6792, Val RMSE: 5688.8735
# Epoch 2/200 Train RMSE: 5290.3992, Val RMSE: 5688.8091
# Epoch 3/200 Train RMSE: 5287.4446, Val RMSE: 5688.7407
# Epoch 4/200 Train RMSE: 5287.6399, Val RMSE: 5688.6538
# Epoch 5/200 Train RMSE: 5288.8076, Val RMSE: 5688.5420
# Epoch 6/200 Train RMSE: 5287.6584, Val RMSE: 5688.3975
# Epoch 7/200 Train RMSE: 5293.6892, Val RMSE: 5688.2114
# Epoch 8/200 Train RMSE: 5291.8997, Val RMSE: 5687.9712
# Epoch 9/200 Train RMSE: 5278.7136, Val RMSE: 5687.6621
# Epoch 10/200 Train RMSE: 5287.7786, Val RMSE: 5687.2671
# Epoch 11/200 Train RMSE: 5276.9189, Val RMSE: 5686.7593
# Epoch 12/200 Train RMSE: 5278.0083, Val RMSE: 5686.1138
# Epoch 13/200 Train RMSE: 5266.5066, Val RMSE: 5685.3013
# Epoch 14/200 Train RMSE: 5289.6819, Val RMSE: 5684.2832
# Epoch 15/200 Train RMSE: 5281.7839, Val RMSE: 5683.0146
# Epoch 16/200 Train RMSE: 5282.8442, Val RMSE: 5681.4297
# Epoch 17/200 Train RMSE: 5273.0520, Val RMSE: 5679.4521
# Epoch 18/200 Train RMSE: 5267.9954, Val RMSE: 5676.9976
# Epoch 19/200 Train RMSE: 5271.4766, Val RMSE: 5673.9795
# Epoch 20/200 Train RMSE: 5267.5359, Val RMSE: 5670.3057
# Epoch 21/200 Train RMSE: 5261.7136, Val RMSE: 5665.8623
# Epoch 22/200 Train RMSE: 5269.1326, Val RMSE: 5660.5405
# Epoch 23/200 Train RMSE: 5267.4583, Val RMSE: 5654.2026
# Epoch 24/200 Train RMSE: 5247.9685, Val RMSE: 5646.6440
# Epoch 25/200 Train RMSE: 5243.8066, Val RMSE: 5637.6958
# Epoch 26/200 Train RMSE: 5246.0479, Val RMSE: 5627.2119
# Epoch 27/200 Train RMSE: 5213.8767, Val RMSE: 5614.9307
# Epoch 28/200 Train RMSE: 5208.2424, Val RMSE: 5600.6406
# Epoch 29/200 Train RMSE: 5197.2434, Val RMSE: 5584.0435
# Epoch 30/200 Train RMSE: 5190.5168, Val RMSE: 5564.8916
# Epoch 31/200 Train RMSE: 5179.1794, Val RMSE: 5542.8726
# Epoch 32/200 Train RMSE: 5160.7395, Val RMSE: 5517.5981
# Epoch 33/200 Train RMSE: 5144.6536, Val RMSE: 5488.6450
# Epoch 34/200 Train RMSE: 5113.7900, Val RMSE: 5455.6899
# Epoch 35/200 Train RMSE: 5081.6133, Val RMSE: 5418.1953
# Epoch 36/200 Train RMSE: 5027.9346, Val RMSE: 5375.5962
# Epoch 37/200 Train RMSE: 5010.9475, Val RMSE: 5327.6489
# Epoch 38/200 Train RMSE: 4976.3254, Val RMSE: 5273.7354
# Epoch 39/200 Train RMSE: 4917.9661, Val RMSE: 5213.4019
# Epoch 40/200 Train RMSE: 4877.5305, Val RMSE: 5146.4360
# Epoch 41/200 Train RMSE: 4819.2749, Val RMSE: 5071.9502
# Epoch 42/200 Train RMSE: 4753.3489, Val RMSE: 4989.2188
# Epoch 43/200 Train RMSE: 4668.5669, Val RMSE: 4898.0664
# Epoch 44/200 Train RMSE: 4600.5142, Val RMSE: 4797.8135
# Epoch 45/200 Train RMSE: 4517.6992, Val RMSE: 4688.1523
# Epoch 46/200 Train RMSE: 4421.6357, Val RMSE: 4568.4644
# Epoch 47/200 Train RMSE: 4301.3013, Val RMSE: 4438.6777
# Epoch 48/200 Train RMSE: 4210.0277, Val RMSE: 4298.8359
# Epoch 49/200 Train RMSE: 4073.1426, Val RMSE: 4147.7881
# Epoch 50/200 Train RMSE: 3941.5256, Val RMSE: 3986.5779
# Epoch 51/200 Train RMSE: 3796.8905, Val RMSE: 3814.5383
# Epoch 52/200 Train RMSE: 3633.7599, Val RMSE: 3632.6074
# Epoch 53/200 Train RMSE: 3476.0471, Val RMSE: 3443.1140
# Epoch 54/200 Train RMSE: 3297.0210, Val RMSE: 3246.9622
# Epoch 55/200 Train RMSE: 3080.9425, Val RMSE: 3048.5847
# Epoch 56/200 Train RMSE: 2890.1050, Val RMSE: 2852.1968
# Epoch 57/200 Train RMSE: 2690.8186, Val RMSE: 2665.0474
# Epoch 58/200 Train RMSE: 2482.0452, Val RMSE: 2496.4866
# Epoch 59/200 Train RMSE: 2247.5508, Val RMSE: 2357.2451
# Epoch 60/200 Train RMSE: 2029.2632, Val RMSE: 2260.5105
# Epoch 61/200 Train RMSE: 1831.6832, Val RMSE: 2218.8865
# Epoch 62/200 Train RMSE: 1637.3659, Val RMSE: 2233.7217
# Epoch 63/200 Train RMSE: 1488.5317, Val RMSE: 2296.7610
# Epoch 64/200 Train RMSE: 1395.0260, Val RMSE: 2381.0559
# Epoch 65/200 Train RMSE: 1334.2864, Val RMSE: 2456.9749
# Epoch 66/200 Train RMSE: 1306.9382, Val RMSE: 2490.4258
# Epoch 67/200 Train RMSE: 1281.6107, Val RMSE: 2465.9885
# Epoch 68/200 Train RMSE: 1233.6530, Val RMSE: 2386.0608
# Epoch 69/200 Train RMSE: 1152.6216, Val RMSE: 2264.9719
# Epoch 70/200 Train RMSE: 1066.7650, Val RMSE: 2121.2854
# Epoch 71/200 Train RMSE: 959.0517, Val RMSE: 1971.4795
# Epoch 72/200 Train RMSE: 885.0026, Val RMSE: 1825.4298
# Epoch 73/200 Train RMSE: 818.5413, Val RMSE: 1697.8406
# Epoch 74/200 Train RMSE: 761.6079, Val RMSE: 1592.2098
# Epoch 75/200 Train RMSE: 708.3131, Val RMSE: 1505.0690
# Epoch 76/200 Train RMSE: 673.3828, Val RMSE: 1432.2847
# Epoch 77/200 Train RMSE: 625.8171, Val RMSE: 1373.7430
# Epoch 78/200 Train RMSE: 583.2686, Val RMSE: 1325.3083
# Epoch 79/200 Train RMSE: 548.5131, Val RMSE: 1284.7286
# Epoch 80/200 Train RMSE: 531.2816, Val RMSE: 1241.2502
# Epoch 81/200 Train RMSE: 520.3275, Val RMSE: 1191.9457
# Epoch 82/200 Train RMSE: 502.3670, Val RMSE: 1139.5350
# Epoch 83/200 Train RMSE: 504.4597, Val RMSE: 1086.0681
# Epoch 84/200 Train RMSE: 497.3946, Val RMSE: 1043.3417
# Epoch 85/200 Train RMSE: 487.3306, Val RMSE: 1011.5920
# Epoch 86/200 Train RMSE: 476.6290, Val RMSE: 995.5802
# Epoch 87/200 Train RMSE: 470.8279, Val RMSE: 988.3088
# Epoch 88/200 Train RMSE: 475.7805, Val RMSE: 986.9513
# Epoch 89/200 Train RMSE: 462.2388, Val RMSE: 991.6382
# Epoch 90/200 Train RMSE: 464.8639, Val RMSE: 999.9725
# Epoch 91/200 Train RMSE: 456.2856, Val RMSE: 1012.4244
# Epoch 92/200 Train RMSE: 447.5460, Val RMSE: 1022.3588
# Epoch 93/200 Train RMSE: 450.7586, Val RMSE: 1031.8768
# Epoch 94/200 Train RMSE: 445.3873, Val RMSE: 1037.9213
# Epoch 95/200 Train RMSE: 440.3595, Val RMSE: 1040.9818
# Epoch 96/200 Train RMSE: 436.1600, Val RMSE: 1043.1743
# Epoch 97/200 Train RMSE: 432.3400, Val RMSE: 1043.7809
# Epoch 98/200 Train RMSE: 430.0629, Val RMSE: 1043.8829
# Epoch 99/200 Train RMSE: 426.1096, Val RMSE: 1042.5920
# Epoch 100/200 Train RMSE: 420.7196, Val RMSE: 1037.3954
# Epoch 101/200 Train RMSE: 416.2330, Val RMSE: 1032.2411
# Epoch 102/200 Train RMSE: 411.6867, Val RMSE: 1026.1056
# Epoch 103/200 Train RMSE: 407.5451, Val RMSE: 1018.9470
# Epoch 104/200 Train RMSE: 401.3455, Val RMSE: 1011.6132
# Epoch 105/200 Train RMSE: 405.2624, Val RMSE: 1000.9575
# Epoch 106/200 Train RMSE: 400.6823, Val RMSE: 992.0997
# Epoch 107/200 Train RMSE: 397.6296, Val RMSE: 984.6039
# Epoch 108/200 Train RMSE: 394.3754, Val RMSE: 976.0690
# Epoch 109/200 Train RMSE: 387.4306, Val RMSE: 969.7087
# Epoch 110/200 Train RMSE: 387.4839, Val RMSE: 963.7467
# Epoch 111/200 Train RMSE: 374.2825, Val RMSE: 958.2017
# Epoch 112/200 Train RMSE: 382.0936, Val RMSE: 955.4180
# Epoch 113/200 Train RMSE: 378.5725, Val RMSE: 951.6664
# Epoch 114/200 Train RMSE: 376.0172, Val RMSE: 948.4913
# Epoch 115/200 Train RMSE: 374.6410, Val RMSE: 944.5672
# Epoch 116/200 Train RMSE: 372.3870, Val RMSE: 941.3113
# Epoch 117/200 Train RMSE: 369.2734, Val RMSE: 937.0063
# Epoch 118/200 Train RMSE: 366.4349, Val RMSE: 933.7389
# Epoch 119/200 Train RMSE: 362.4220, Val RMSE: 928.5596
# Epoch 120/200 Train RMSE: 357.8769, Val RMSE: 923.3334
# Epoch 121/200 Train RMSE: 358.7759, Val RMSE: 917.8549
# Epoch 122/200 Train RMSE: 356.8404, Val RMSE: 915.1194
# Epoch 123/200 Train RMSE: 353.4797, Val RMSE: 911.4527
# Epoch 124/200 Train RMSE: 352.6100, Val RMSE: 906.8784
# Epoch 125/200 Train RMSE: 348.6557, Val RMSE: 902.3436
# Epoch 126/200 Train RMSE: 343.4306, Val RMSE: 898.5886
# Epoch 127/200 Train RMSE: 346.0566, Val RMSE: 896.5998
# Epoch 128/200 Train RMSE: 344.4612, Val RMSE: 893.6931
# Epoch 129/200 Train RMSE: 341.8431, Val RMSE: 890.2130
# Epoch 130/200 Train RMSE: 339.1341, Val RMSE: 887.1597
# Epoch 131/200 Train RMSE: 337.6451, Val RMSE: 882.5958
# Epoch 132/200 Train RMSE: 328.1893, Val RMSE: 877.0768
# Epoch 133/200 Train RMSE: 333.3047, Val RMSE: 872.7314
# Epoch 134/200 Train RMSE: 332.0771, Val RMSE: 870.3515
# Epoch 135/200 Train RMSE: 329.4799, Val RMSE: 866.2817
# Epoch 136/200 Train RMSE: 323.3997, Val RMSE: 861.8002
# Epoch 137/200 Train RMSE: 326.7506, Val RMSE: 857.8222
# Epoch 138/200 Train RMSE: 323.1803, Val RMSE: 852.5449
# Epoch 139/200 Train RMSE: 323.2406, Val RMSE: 849.6626
# Epoch 140/200 Train RMSE: 319.3850, Val RMSE: 846.4890
# Epoch 141/200 Train RMSE: 318.4755, Val RMSE: 841.5789
# Epoch 142/200 Train RMSE: 317.6367, Val RMSE: 839.5400
# Epoch 143/200 Train RMSE: 317.5868, Val RMSE: 838.0550
# Epoch 144/200 Train RMSE: 315.2115, Val RMSE: 834.8630
# Epoch 145/200 Train RMSE: 314.3409, Val RMSE: 832.8236
# Epoch 146/200 Train RMSE: 306.2333, Val RMSE: 830.2530
# Epoch 147/200 Train RMSE: 310.4234, Val RMSE: 829.0197
# Epoch 148/200 Train RMSE: 304.3529, Val RMSE: 825.3253
# Epoch 149/200 Train RMSE: 306.5780, Val RMSE: 823.3079
# Epoch 150/200 Train RMSE: 306.6653, Val RMSE: 820.4036
# Epoch 151/200 Train RMSE: 301.4052, Val RMSE: 817.1079
# Epoch 152/200 Train RMSE: 302.8775, Val RMSE: 812.3529
# Epoch 153/200 Train RMSE: 296.9478, Val RMSE: 809.3357
# Epoch 154/200 Train RMSE: 298.0952, Val RMSE: 805.0939
# Epoch 155/200 Train RMSE: 297.9361, Val RMSE: 804.3209
# Epoch 156/200 Train RMSE: 298.1643, Val RMSE: 802.9214
# Epoch 157/200 Train RMSE: 295.8433, Val RMSE: 801.5865
# Epoch 158/200 Train RMSE: 295.4466, Val RMSE: 802.3016
# Epoch 159/200 Train RMSE: 291.0659, Val RMSE: 798.7853
# Epoch 160/200 Train RMSE: 293.7435, Val RMSE: 795.6404
# Epoch 161/200 Train RMSE: 293.0252, Val RMSE: 792.4525
# Epoch 162/200 Train RMSE: 291.4528, Val RMSE: 788.8855
# Epoch 163/200 Train RMSE: 290.3086, Val RMSE: 787.3729
# Epoch 164/200 Train RMSE: 287.3536, Val RMSE: 786.0022
# Epoch 165/200 Train RMSE: 285.0649, Val RMSE: 782.7222
# Epoch 166/200 Train RMSE: 286.9556, Val RMSE: 779.4762
# Epoch 167/200 Train RMSE: 279.8951, Val RMSE: 776.3632
# Epoch 168/200 Train RMSE: 280.5961, Val RMSE: 771.6562
# Epoch 169/200 Train RMSE: 282.6652, Val RMSE: 769.3433
# Epoch 170/200 Train RMSE: 281.5806, Val RMSE: 769.4550
# Epoch 171/200 Train RMSE: 275.6351, Val RMSE: 767.5145
# Epoch 172/200 Train RMSE: 280.2312, Val RMSE: 767.2433
# Epoch 173/200 Train RMSE: 279.1344, Val RMSE: 763.3427
# Epoch 174/200 Train RMSE: 277.0625, Val RMSE: 758.4964
# Epoch 175/200 Train RMSE: 273.2667, Val RMSE: 755.7593
# Epoch 176/200 Train RMSE: 273.3779, Val RMSE: 755.7092
# Epoch 177/200 Train RMSE: 274.3794, Val RMSE: 754.5992
# Epoch 178/200 Train RMSE: 272.9437, Val RMSE: 754.1675
# Epoch 179/200 Train RMSE: 265.9751, Val RMSE: 755.0375
# Epoch 180/200 Train RMSE: 273.7616, Val RMSE: 756.4778
# Epoch 181/200 Train RMSE: 270.6733, Val RMSE: 751.9503
# Epoch 182/200 Train RMSE: 267.8046, Val RMSE: 743.8001
# Epoch 183/200 Train RMSE: 268.4429, Val RMSE: 738.0525
# Epoch 184/200 Train RMSE: 268.2286, Val RMSE: 734.8547
# Epoch 185/200 Train RMSE: 263.1769, Val RMSE: 733.8767
# Epoch 186/200 Train RMSE: 266.1024, Val RMSE: 735.9018
# Epoch 187/200 Train RMSE: 263.9173, Val RMSE: 735.3538
# Epoch 188/200 Train RMSE: 263.4892, Val RMSE: 731.5491
# Epoch 189/200 Train RMSE: 262.3656, Val RMSE: 730.0270
# Epoch 190/200 Train RMSE: 260.4838, Val RMSE: 729.4040
# Epoch 191/200 Train RMSE: 260.5093, Val RMSE: 726.4500
# Epoch 192/200 Train RMSE: 258.4792, Val RMSE: 722.1729
# Epoch 193/200 Train RMSE: 258.7898, Val RMSE: 720.9585
# Epoch 194/200 Train RMSE: 258.7321, Val RMSE: 720.9914
# Epoch 195/200 Train RMSE: 257.5777, Val RMSE: 721.3697
# Epoch 196/200 Train RMSE: 252.3422, Val RMSE: 718.5917
# Epoch 197/200 Train RMSE: 254.4226, Val RMSE: 714.0049
# Epoch 198/200 Train RMSE: 246.3381, Val RMSE: 709.2799
# Epoch 199/200 Train RMSE: 252.2555, Val RMSE: 707.6938
# Epoch 200/200 Train RMSE: 253.5467, Val RMSE: 706.5379
# RMSE: 745.98779296875
# R²: 0.729631781578064

# %% [markdown]
# ## Hyperparameter tuning with Optuna
#
# In this section we use Optuna to tune the neural network hyperparameters (number of layers, neurons, dropout, learning rate, and batch size).
# We then compare the tuned model performance against the initial neural network using RMSE and R² on the test set.

# %%
import optuna

# If Optuna is not installed, uncomment and run the following line once:
# !pip install optuna

def create_model(trial, input_dim):
    """Create a feedforward network whose size/depth are tuned by Optuna."""
    n_layers = trial.suggest_int("n_layers", 1, 3)
    n_neurons = trial.suggest_int("n_neurons", 64, 512, step=64)
    dropout_rate = trial.suggest_float("dropout", 0.0, 0.4)
    
    layers = []
    in_features = input_dim
    for _ in range(n_layers):
        layers.append(nn.Linear(in_features, n_neurons))
        layers.append(nn.ReLU())
        if dropout_rate > 0:
            layers.append(nn.Dropout(dropout_rate))
        in_features = n_neurons
    layers.append(nn.Linear(in_features, 1))
    return nn.Sequential(*layers).to(device)


def objective(trial):
    # Hyperparameters
    lr = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 128])
    max_epochs = 80
    patience = 10
    
    # Datasets / loaders
    train_dataset = TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train))
    val_dataset   = TensorDataset(torch.from_numpy(X_val),   torch.from_numpy(y_val))
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False)
    
    model = create_model(trial, X_train.shape[1])
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = RMSELoss()
    
    best_val_loss = float("inf")
    patience_counter = 0
    
    for epoch in range(max_epochs):
        # ---- Train ----
        model.train()
        running_train_loss = 0.0
        for batch_X, batch_y in train_loader:
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)
            
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            
            running_train_loss += loss.item()
        
        # ---- Validation ----
        model.eval()
        val_losses = []
        with torch.no_grad():
            for batch_X, batch_y in val_loader:
                batch_X = batch_X.to(device)
                batch_y = batch_y.to(device)
                outputs = model(batch_X)
                vloss = criterion(outputs, batch_y)
                val_losses.append(vloss.item())
        
        mean_val_loss = float(np.mean(val_losses))
        
        # Early stopping on validation RMSE
        if mean_val_loss < best_val_loss:
            best_val_loss = mean_val_loss
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                break
    
    # Optuna will minimize this value
    return best_val_loss


# Run Optuna study
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30, show_progress_bar=False)

print("Number of finished trials:", len(study.trials))
print("Best trial value (val RMSE):", study.best_value)
print("Best hyperparameters:")
for k, v in study.best_trial.params.items():
    print(f"  {k}: {v}")

# %%
# Train a new model using the best hyperparameters found by Optuna
best_params = study.best_trial.params

tuned_batch_size = best_params.get("batch_size", 64)
tuned_lr = best_params.get("lr", 1e-3)
tuned_n_layers = best_params.get("n_layers", 2)
tuned_n_neurons = best_params.get("n_neurons", 128)
tuned_dropout = best_params.get("dropout", 0.0)

print("Training tuned model with:")
print("  batch_size:", tuned_batch_size)
print("  lr:", tuned_lr)
print("  n_layers:", tuned_n_layers)
print("  n_neurons:", tuned_n_neurons)
print("  dropout:", tuned_dropout)

# Datasets / loaders (train + val are kept separate, early stopping on val)
train_dataset = TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train))
val_dataset   = TensorDataset(torch.from_numpy(X_val),   torch.from_numpy(y_val))
test_dataset  = TensorDataset(torch.from_numpy(X_test))

train_loader = DataLoader(train_dataset, batch_size=tuned_batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=tuned_batch_size, shuffle=False)
test_loader  = DataLoader(test_dataset,  batch_size=tuned_batch_size, shuffle=False)

# Build tuned model
def build_tuned_model(input_dim):
    layers = []
    in_features = input_dim
    for _ in range(tuned_n_layers):
        layers.append(nn.Linear(in_features, tuned_n_neurons))
        layers.append(nn.ReLU())
        if tuned_dropout > 0:
            layers.append(nn.Dropout(tuned_dropout))
        in_features = tuned_n_neurons
    layers.append(nn.Linear(in_features, 1))
    return nn.Sequential(*layers).to(device)

tuned_model = build_tuned_model(X_train.shape[1])
optimizer = torch.optim.Adam(tuned_model.parameters(), lr=tuned_lr)
criterion = RMSELoss()

max_epochs = 200
patience = 20
best_val_loss = float("inf")
patience_counter = 0
best_state_dict_tuned = tuned_model.state_dict()

tuned_train_losses = []
tuned_val_losses = []

for epoch in range(max_epochs):
    # Train
    tuned_model.train()
    running_train_loss = 0.0
    for batch_X, batch_y in train_loader:
        batch_X = batch_X.to(device)
        batch_y = batch_y.to(device)
        
        optimizer.zero_grad()
        outputs = tuned_model(batch_X)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        
        running_train_loss += loss.item()
    
    train_loss = running_train_loss / len(train_loader)
    
    # Validation
    tuned_model.eval()
    val_losses = []
    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)
            outputs = tuned_model(batch_X)
            vloss = criterion(outputs, batch_y)
            val_losses.append(vloss.item())
    
    val_loss = float(np.mean(val_losses))
    
    tuned_train_losses.append(train_loss)
    tuned_val_losses.append(val_loss)
    
    # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state_dict_tuned = tuned_model.state_dict()
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"[Tuned] Early stopping at epoch {epoch+1}")
            break

# Load best weights
tuned_model.load_state_dict(best_state_dict_tuned)

# Evaluate tuned model on test set
tuned_model.eval()
y_pred_test_tuned = []

with torch.no_grad():
    for (batch_X,) in test_loader:
        batch_X = batch_X.to(device)
        preds = tuned_model(batch_X).cpu().numpy().reshape(-1)
        y_pred_test_tuned.extend(preds)

y_pred_test_tuned = np.array(y_pred_test_tuned, dtype=np.float32)

from sklearn.metrics import root_mean_squared_error, r2_score

rmse_tuned = root_mean_squared_error(y_test, y_pred_test_tuned)
r2_tuned   = r2_score(y_test, y_pred_test_tuned)

print("Tuned model RMSE:", rmse_tuned)
print("Tuned model R²:", r2_tuned)

# %%
import matplotlib.pyplot as plt

# 1) Optuna optimization history (validation RMSE per trial)
trial_numbers = [t.number for t in study.trials if t.value is not None]
trial_values  = [t.value  for t in study.trials if t.value is not None]

plt.figure(figsize=(8, 5))
plt.plot(trial_numbers, trial_values, marker="o")
plt.xlabel("Trial")
plt.ylabel("Validation RMSE")
plt.title("Optuna optimization history (validation RMSE)")
plt.grid(True)
plt.tight_layout()
plt.show()

# 2) Compare RMSE between initial NN and tuned NN
baseline_rmse = rmse
baseline_r2   = r2

models = ["Initial NN", "Optuna-tuned NN"]
rmse_values = [baseline_rmse, rmse_tuned]

plt.figure(figsize=(6, 4))
plt.bar(models, rmse_values)
plt.ylabel("RMSE")
plt.title("RMSE comparison: initial vs Optuna-tuned NN")
plt.tight_layout()
plt.show()

# 3) Compare R² between initial NN and tuned NN
r2_values = [baseline_r2, r2_tuned]

plt.figure(figsize=(6, 4))
plt.bar(models, r2_values)
plt.ylabel("R²")
plt.title("R² comparison: initial vs Optuna-tuned NN")
plt.tight_layout()
plt.show()
