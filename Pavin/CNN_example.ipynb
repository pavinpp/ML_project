# %% [markdown]
# This notebook shows how to apply CNN to predict the global temperature map, based on the 1-D time series of CO2 & CH4.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import torch
import torch.nn as nn

from utils import * 

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2

plt.rcParams['savefig.dpi'] = 400
plt.rcParams['font.size'] = 13
plt.rcParams["legend.frameon"] = False

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
cwd = os.getcwd()
train_path = "gs://leap-persistent/jbusecke/data/climatebench/train_val/"
test_path = "gs://leap-persistent/jbusecke/data/climatebench/test/"

# %% [markdown]
# ### 1. data preprocssing: prepare data for training & test sets

# %% [markdown]
# #### import data as training & test sets
#
# Here we train CNN using simulations from 3 historical and 3 future scenarios. Then we test the trained NN using the ssp245 scenario.

# %%
# Training set
train_files = ["historical", "ssp585", "ssp126", "ssp370","hist-GHG","hist-aer"]
X_train_xr, X_length  = prepare_predictor(train_files,train_path)
y_train_xr, y_length  = prepare_predictand(train_files,train_path)

# Test set
X_test_xr, _ = prepare_predictor('ssp245', data_path=test_path,time_reindex=False)
y_test_xr, _ = prepare_predictand('ssp245',data_path=test_path,time_reindex=False)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #### select relevant variables
#
# predictors: CO2 & CH4 <br/>
# predictand: tas

# %%
X_train_df = pd.DataFrame({"CO2": X_train_xr["CO2"].data,
                           "CH4": X_train_xr["CH4"].data
                          }, index=X_train_xr["CO2"].coords['time'].data)

X_test_df  = pd.DataFrame({"CO2": X_test_xr["CO2"].data,
                           "CH4": X_test_xr["CH4"].data
                          }, index=X_test_xr["CO2"].coords['time'].data)

y_train = y_train_xr['tas'].data
y_test  = y_test_xr['tas'].data

# %% [markdown]
# This is how our predictors & predictand data look like. Our predictors are **1-D** time series of CO2 & CH4.

# %%
X_train_df.head()
# Out:
#         CO2       CH4
# 0  0.188297  0.031306
# 1  0.377244  0.031742
# 2  0.573814  0.032178
# 3  0.778848  0.032614
# 4  1.020320  0.033049

# %% [markdown]
# The predictand tas is **2-D** map - this point is different from the NN case

# %%
plt.imshow(np.flip(y_train[0],axis=0),cmap='RdBu_r',vmin=-3,vmax=3)
plt.colorbar()

# %% [markdown]
# #### Data normalization

# %% [markdown]
# Let's normalize the input predictors by there mean & standard deviation

# %%
# Standardization
mean, std = X_train_df.mean(), X_train_df.std()

X_train_df   = (X_train_df - mean)/std
X_test_df    = (X_test_df - mean)/std

X_train = X_train_df.to_numpy()
X_test = X_test_df.to_numpy()

# Convert to PyTorch datasets
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)

train_dataset = torch.utils.data.TensorDataset(torch.FloatTensor(X_train), \
                                               y_train_tensor)
test_dataset = torch.utils.data.TensorDataset(torch.FloatTensor(X_test))

# Split into train and validation sets
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (753, 2) (753, 96, 144) (86, 2) (86, 96, 144)

# %% [markdown]
# ### 2. Define the CNN architecture
#
#
# The CNN architecture used here consists of several upsampling blocks.
#
# We set the dimensions of the hidden layers (i.e., number of neurons) in order to reach the size of the target maps (96x144) in a proportional way (in particular by doubling the dimensions in each upsampling block) through the various upsampling blocks.

# %% [markdown]
# ![image.png](attachment:4547f967-577a-4c0b-8a7f-8e304f6a64bb.png)

# %% [markdown]
# Here are the hyperparameters for the CNN training. Note that these hyperparameters here are for demonstration purposes only and they are not optimized.

# %%
n_filters  = 32  # number of filters
n_neurons  = 32  # number of neurons in the Dense layer
activation     = 'ReLU' # activation function
kernel_size    = 4
learning_rate  = 0.001
minibatch_size = 64
num_epochs     = 100

# %%
def make_CNN_model(input_dim, n_filters, activation, kernel_size):
    layers = []
    layers.append(nn.Linear(input_dim, n_filters * 12 * 18))  # shape: (batch_size, 6912) assuming n_filters=32
    layers.append(getattr(nn, activation)())
    
    # custom reshape layer
    class Reshape(nn.Module):
        def __init__(self, shape):
            super().__init__()
            self.shape = shape
        
        def forward(self, x):
            return x.view(-1, *self.shape)
    
    # note that pytorch uses (N,C,H,W)
    layers.append(Reshape((n_filters, 12, 18)))  # shape: (batch_size, 32, 12, 18) 
    
    layers.append(nn.ConvTranspose2d(n_filters, n_filters, kernel_size=kernel_size, stride=2, padding=1, output_padding=0))  # shape: (batch_size, 32, 24, 36) - upsampled to 24x36
    layers.append(getattr(nn, activation)())
    layers.append(nn.ConvTranspose2d(n_filters, n_filters, kernel_size=kernel_size, stride=2, padding=1, output_padding=0))  # shape: (batch_size, 32, 48, 72) - upsampled to 48x72
    layers.append(getattr(nn, activation)())
    layers.append(nn.ConvTranspose2d(n_filters, n_filters, kernel_size=kernel_size, stride=2, padding=1, output_padding=0))  # shape: (batch_size, 32, 96, 144) - upsampled to 96x144
    layers.append(getattr(nn, activation)())
    # output layer
    layers.append(nn.Conv2d(n_filters, 1, kernel_size=3, padding=1))  # shape: (batch_size, 1, 96, 144) - final output
    
    return nn.Sequential(*layers)

# %%
model_mse = make_CNN_model(X_train.shape[1], n_filters, activation, kernel_size)

# %%
print("Model:")
print(model_mse)
print(f"\nTotal parameters: {sum(p.numel() for p in model_mse.parameters())}")
# Out:
# Model:
# Sequential(
#   (0): Linear(in_features=2, out_features=6912, bias=True)
#   (1): ReLU()
#   (2): Reshape()
#   (3): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): ReLU()
#   (5): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (6): ReLU()
#   (7): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (8): ReLU()
#   (9): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
#
# Total parameters: 70273

# %% [markdown]
# ### 3. Train & save the CNN model

# %%
def pytorch_train(model, optimizer, criterion, device):
    best_val_loss = float('inf')
    patience_counter = 0
    patience = 20
    
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
       # training
       model.train()
       train_loss = 0.0
       for batch_X, batch_y in train_loader:
           batch_X = batch_X.to(device)
           batch_y = batch_y.to(device)
           # forward pass
           optimizer.zero_grad()
           outputs = model(batch_X)
           loss = criterion(outputs, batch_y)
           # backward pass
           loss.backward()
           optimizer.step()
           train_loss += loss.item()
    
        # validation
       model.eval()
       val_loss = 0.0
       with torch.no_grad():
           for batch_X, batch_y in val_loader:
               batch_X = batch_X.to(device)
               batch_y = batch_y.to(device)
               
               outputs = model(batch_X)
               loss = criterion(outputs, batch_y)
               val_loss += loss.item()
       
       train_loss /= len(train_loader)
       val_loss /= len(val_loader)
    
       train_losses.append(train_loss)
       val_losses.append(val_loss)
       
       print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')
       
       if val_loss < best_val_loss:
           best_val_loss = val_loss
           patience_counter = 0
       else:
           patience_counter += 1
           if patience_counter >= patience:
               print(f'Early stopping at epoch {epoch+1}')
               break
   
    return train_losses, val_losses

# %%
# Create data loaders for batched training
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=minibatch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=minibatch_size, shuffle=False)

# %%
optimizer_mse = torch.optim.Adam(model_mse.parameters(), lr=learning_rate)
# Loss function
mse_loss = nn.MSELoss()

# %%
train_losses_mse, val_losses_mse = pytorch_train(model_mse.to(device), optimizer_mse, criterion = mse_loss, device = device)
# Out:
# Epoch 1/100, Train Loss: 2.9086, Val Loss: 2.1844
# Epoch 2/100, Train Loss: 2.1331, Val Loss: 2.0109
# Epoch 3/100, Train Loss: 2.0037, Val Loss: 1.8724
# Epoch 4/100, Train Loss: 1.8246, Val Loss: 1.7128
# Epoch 5/100, Train Loss: 1.6804, Val Loss: 1.5528
# Epoch 6/100, Train Loss: 1.4434, Val Loss: 1.3537
# Epoch 7/100, Train Loss: 1.2038, Val Loss: 1.1152
# Epoch 8/100, Train Loss: 0.9444, Val Loss: 0.8818
# Epoch 9/100, Train Loss: 0.7722, Val Loss: 0.8070
# Epoch 10/100, Train Loss: 0.6935, Val Loss: 0.7061
# Epoch 11/100, Train Loss: 0.6209, Val Loss: 0.6636
# Epoch 12/100, Train Loss: 0.5875, Val Loss: 0.6246
# Epoch 13/100, Train Loss: 0.5648, Val Loss: 0.6066
# Epoch 14/100, Train Loss: 0.5354, Val Loss: 0.5757
# Epoch 15/100, Train Loss: 0.4973, Val Loss: 0.5516
# Epoch 16/100, Train Loss: 0.4834, Val Loss: 0.5321
# Epoch 17/100, Train Loss: 0.4788, Val Loss: 0.5175
# Epoch 18/100, Train Loss: 0.4613, Val Loss: 0.5043
# Epoch 19/100, Train Loss: 0.4509, Val Loss: 0.4901
# Epoch 20/100, Train Loss: 0.4376, Val Loss: 0.4845
# Epoch 21/100, Train Loss: 0.4384, Val Loss: 0.4864
# Epoch 22/100, Train Loss: 0.4257, Val Loss: 0.4643
# Epoch 23/100, Train Loss: 0.4068, Val Loss: 0.4587
# Epoch 24/100, Train Loss: 0.4108, Val Loss: 0.4508
# Epoch 25/100, Train Loss: 0.3981, Val Loss: 0.4585
# Epoch 26/100, Train Loss: 0.4066, Val Loss: 0.4394
# Epoch 27/100, Train Loss: 0.3960, Val Loss: 0.4329
# Epoch 28/100, Train Loss: 0.3955, Val Loss: 0.4413
# Epoch 29/100, Train Loss: 0.3909, Val Loss: 0.4451
# Epoch 30/100, Train Loss: 0.3932, Val Loss: 0.4276
# Epoch 31/100, Train Loss: 0.3809, Val Loss: 0.4228
# Epoch 32/100, Train Loss: 0.3867, Val Loss: 0.4338
# Epoch 33/100, Train Loss: 0.3885, Val Loss: 0.4176
# Epoch 34/100, Train Loss: 0.3788, Val Loss: 0.4232
# Epoch 35/100, Train Loss: 0.3861, Val Loss: 0.4150
# Epoch 36/100, Train Loss: 0.3752, Val Loss: 0.4104
# Epoch 37/100, Train Loss: 0.3717, Val Loss: 0.4087
# Epoch 38/100, Train Loss: 0.3698, Val Loss: 0.4102
# Epoch 39/100, Train Loss: 0.3677, Val Loss: 0.4054
# Epoch 40/100, Train Loss: 0.3686, Val Loss: 0.4020
# Epoch 41/100, Train Loss: 0.3676, Val Loss: 0.4004
# Epoch 42/100, Train Loss: 0.3600, Val Loss: 0.4049
# Epoch 43/100, Train Loss: 0.3624, Val Loss: 0.4054
# Epoch 44/100, Train Loss: 0.3678, Val Loss: 0.4032
# Epoch 45/100, Train Loss: 0.3679, Val Loss: 0.4017
# Epoch 46/100, Train Loss: 0.3587, Val Loss: 0.3932
# Epoch 47/100, Train Loss: 0.3557, Val Loss: 0.3903
# Epoch 48/100, Train Loss: 0.3567, Val Loss: 0.3879
# Epoch 49/100, Train Loss: 0.3549, Val Loss: 0.3873
# Epoch 50/100, Train Loss: 0.3551, Val Loss: 0.3843
# Epoch 51/100, Train Loss: 0.3549, Val Loss: 0.3901
# Epoch 52/100, Train Loss: 0.3467, Val Loss: 0.3836
# Epoch 53/100, Train Loss: 0.3458, Val Loss: 0.3891
# Epoch 54/100, Train Loss: 0.3459, Val Loss: 0.3784
# Epoch 55/100, Train Loss: 0.3430, Val Loss: 0.3879
# Epoch 56/100, Train Loss: 0.3500, Val Loss: 0.3965
# Epoch 57/100, Train Loss: 0.3509, Val Loss: 0.3880
# Epoch 58/100, Train Loss: 0.3502, Val Loss: 0.3907
# Epoch 59/100, Train Loss: 0.3533, Val Loss: 0.3878
# Epoch 60/100, Train Loss: 0.3528, Val Loss: 0.3775
# Epoch 61/100, Train Loss: 0.3467, Val Loss: 0.3824
# Epoch 62/100, Train Loss: 0.3444, Val Loss: 0.3748
# Epoch 63/100, Train Loss: 0.3448, Val Loss: 0.3681
# Epoch 64/100, Train Loss: 0.3502, Val Loss: 0.3880
# Epoch 65/100, Train Loss: 0.3588, Val Loss: 0.3867
# Epoch 66/100, Train Loss: 0.3505, Val Loss: 0.3953
# Epoch 67/100, Train Loss: 0.3677, Val Loss: 0.3743
# Epoch 68/100, Train Loss: 0.3448, Val Loss: 0.3707
# Epoch 69/100, Train Loss: 0.3424, Val Loss: 0.3774
# Epoch 70/100, Train Loss: 0.3395, Val Loss: 0.3637
# Epoch 71/100, Train Loss: 0.3386, Val Loss: 0.3760
# Epoch 72/100, Train Loss: 0.3447, Val Loss: 0.3826
# Epoch 73/100, Train Loss: 0.3441, Val Loss: 0.3664
# Epoch 74/100, Train Loss: 0.3399, Val Loss: 0.3696
# Epoch 75/100, Train Loss: 0.3398, Val Loss: 0.3612
# Epoch 76/100, Train Loss: 0.3357, Val Loss: 0.3701
# Epoch 77/100, Train Loss: 0.3391, Val Loss: 0.3632
# Epoch 78/100, Train Loss: 0.3411, Val Loss: 0.3645
# Epoch 79/100, Train Loss: 0.3331, Val Loss: 0.3712
# Epoch 80/100, Train Loss: 0.3349, Val Loss: 0.3606
# Epoch 81/100, Train Loss: 0.3353, Val Loss: 0.3666
# Epoch 82/100, Train Loss: 0.3343, Val Loss: 0.3609
# Epoch 83/100, Train Loss: 0.3338, Val Loss: 0.3647
# Epoch 84/100, Train Loss: 0.3332, Val Loss: 0.3615
# Epoch 85/100, Train Loss: 0.3351, Val Loss: 0.3588
# Epoch 86/100, Train Loss: 0.3271, Val Loss: 0.3583
# Epoch 87/100, Train Loss: 0.3320, Val Loss: 0.3628
# Epoch 88/100, Train Loss: 0.3345, Val Loss: 0.3684
# Epoch 89/100, Train Loss: 0.3305, Val Loss: 0.3608
# Epoch 90/100, Train Loss: 0.3408, Val Loss: 0.3580
# Epoch 91/100, Train Loss: 0.3320, Val Loss: 0.3710
# Epoch 92/100, Train Loss: 0.3383, Val Loss: 0.3650
# Epoch 93/100, Train Loss: 0.3320, Val Loss: 0.3588
# Epoch 94/100, Train Loss: 0.3323, Val Loss: 0.3557
# Epoch 95/100, Train Loss: 0.3254, Val Loss: 0.3609
# Epoch 96/100, Train Loss: 0.3259, Val Loss: 0.3543
# Epoch 97/100, Train Loss: 0.3278, Val Loss: 0.3650
# Epoch 98/100, Train Loss: 0.3314, Val Loss: 0.3647
# Epoch 99/100, Train Loss: 0.3297, Val Loss: 0.3604
# Epoch 100/100, Train Loss: 0.3274, Val Loss: 0.3610

# %%
plot_history(train_losses_mse, val_losses_mse)

# %%
model_mae = make_CNN_model(X_train.shape[1], n_filters, activation, kernel_size)
# L1Loss = MAE
mae_loss = nn.L1Loss(reduction='mean') 
optimizer_mae = torch.optim.Adam(model_mae.parameters(), lr=learning_rate)
train_losses_mae, val_losses_mae = pytorch_train(model_mae.to(device), optimizer_mae, criterion = mae_loss, device = device)
# Out:
# Epoch 1/100, Train Loss: 0.9794, Val Loss: 0.9313
# Epoch 2/100, Train Loss: 0.9264, Val Loss: 0.9091
# Epoch 3/100, Train Loss: 0.8894, Val Loss: 0.8624
# Epoch 4/100, Train Loss: 0.8087, Val Loss: 0.7780
# Epoch 5/100, Train Loss: 0.7135, Val Loss: 0.6896
# Epoch 6/100, Train Loss: 0.6221, Val Loss: 0.6188
# Epoch 7/100, Train Loss: 0.5747, Val Loss: 0.5839
# Epoch 8/100, Train Loss: 0.5414, Val Loss: 0.5535
# Epoch 9/100, Train Loss: 0.5221, Val Loss: 0.5345
# Epoch 10/100, Train Loss: 0.5090, Val Loss: 0.5208
# Epoch 11/100, Train Loss: 0.4928, Val Loss: 0.5118
# Epoch 12/100, Train Loss: 0.4813, Val Loss: 0.5048
# Epoch 13/100, Train Loss: 0.4791, Val Loss: 0.4979
# Epoch 14/100, Train Loss: 0.4678, Val Loss: 0.4874
# Epoch 15/100, Train Loss: 0.4578, Val Loss: 0.4794
# Epoch 16/100, Train Loss: 0.4525, Val Loss: 0.4742
# Epoch 17/100, Train Loss: 0.4452, Val Loss: 0.4742
# Epoch 18/100, Train Loss: 0.4433, Val Loss: 0.4691
# Epoch 19/100, Train Loss: 0.4429, Val Loss: 0.4722
# Epoch 20/100, Train Loss: 0.4417, Val Loss: 0.4589
# Epoch 21/100, Train Loss: 0.4307, Val Loss: 0.4617
# Epoch 22/100, Train Loss: 0.4300, Val Loss: 0.4553
# Epoch 23/100, Train Loss: 0.4273, Val Loss: 0.4537
# Epoch 24/100, Train Loss: 0.4278, Val Loss: 0.4570
# Epoch 25/100, Train Loss: 0.4266, Val Loss: 0.4502
# Epoch 26/100, Train Loss: 0.4259, Val Loss: 0.4531
# Epoch 27/100, Train Loss: 0.4235, Val Loss: 0.4486
# Epoch 28/100, Train Loss: 0.4229, Val Loss: 0.4467
# Epoch 29/100, Train Loss: 0.4194, Val Loss: 0.4451
# Epoch 30/100, Train Loss: 0.4165, Val Loss: 0.4468
# Epoch 31/100, Train Loss: 0.4201, Val Loss: 0.4424
# Epoch 32/100, Train Loss: 0.4170, Val Loss: 0.4423
# Epoch 33/100, Train Loss: 0.4134, Val Loss: 0.4405
# Epoch 34/100, Train Loss: 0.4137, Val Loss: 0.4394
# Epoch 35/100, Train Loss: 0.4144, Val Loss: 0.4417
# Epoch 36/100, Train Loss: 0.4122, Val Loss: 0.4384
# Epoch 37/100, Train Loss: 0.4125, Val Loss: 0.4411
# Epoch 38/100, Train Loss: 0.4137, Val Loss: 0.4364
# Epoch 39/100, Train Loss: 0.4123, Val Loss: 0.4371
# Epoch 40/100, Train Loss: 0.4120, Val Loss: 0.4393
# Epoch 41/100, Train Loss: 0.4132, Val Loss: 0.4440
# Epoch 42/100, Train Loss: 0.4103, Val Loss: 0.4379
# Epoch 43/100, Train Loss: 0.4123, Val Loss: 0.4332
# Epoch 44/100, Train Loss: 0.4081, Val Loss: 0.4339
# Epoch 45/100, Train Loss: 0.4078, Val Loss: 0.4345
# Epoch 46/100, Train Loss: 0.4065, Val Loss: 0.4326
# Epoch 47/100, Train Loss: 0.4021, Val Loss: 0.4328
# Epoch 48/100, Train Loss: 0.4056, Val Loss: 0.4333
# Epoch 49/100, Train Loss: 0.4058, Val Loss: 0.4332
# Epoch 50/100, Train Loss: 0.4076, Val Loss: 0.4379
# Epoch 51/100, Train Loss: 0.4084, Val Loss: 0.4324
# Epoch 52/100, Train Loss: 0.4053, Val Loss: 0.4314
# Epoch 53/100, Train Loss: 0.4044, Val Loss: 0.4318
# Epoch 54/100, Train Loss: 0.4029, Val Loss: 0.4294
# Epoch 55/100, Train Loss: 0.4041, Val Loss: 0.4303
# Epoch 56/100, Train Loss: 0.4057, Val Loss: 0.4364
# Epoch 57/100, Train Loss: 0.4073, Val Loss: 0.4312
# Epoch 58/100, Train Loss: 0.4040, Val Loss: 0.4282
# Epoch 59/100, Train Loss: 0.4052, Val Loss: 0.4290
# Epoch 60/100, Train Loss: 0.4011, Val Loss: 0.4302
# Epoch 61/100, Train Loss: 0.4013, Val Loss: 0.4286
# Epoch 62/100, Train Loss: 0.4002, Val Loss: 0.4315
# Epoch 63/100, Train Loss: 0.4041, Val Loss: 0.4320
# Epoch 64/100, Train Loss: 0.4075, Val Loss: 0.4270
# Epoch 65/100, Train Loss: 0.4023, Val Loss: 0.4265
# Epoch 66/100, Train Loss: 0.4072, Val Loss: 0.4277
# Epoch 67/100, Train Loss: 0.4064, Val Loss: 0.4305
# Epoch 68/100, Train Loss: 0.4082, Val Loss: 0.4298
# Epoch 69/100, Train Loss: 0.4061, Val Loss: 0.4290
# Epoch 70/100, Train Loss: 0.4056, Val Loss: 0.4259
# Epoch 71/100, Train Loss: 0.4009, Val Loss: 0.4287
# Epoch 72/100, Train Loss: 0.4016, Val Loss: 0.4257
# Epoch 73/100, Train Loss: 0.3977, Val Loss: 0.4274
# Epoch 74/100, Train Loss: 0.4017, Val Loss: 0.4263
# Epoch 75/100, Train Loss: 0.4001, Val Loss: 0.4317
# Epoch 76/100, Train Loss: 0.4041, Val Loss: 0.4256
# Epoch 77/100, Train Loss: 0.4012, Val Loss: 0.4296
# Epoch 78/100, Train Loss: 0.4036, Val Loss: 0.4272
# Epoch 79/100, Train Loss: 0.3995, Val Loss: 0.4262
# Epoch 80/100, Train Loss: 0.3997, Val Loss: 0.4276
# Epoch 81/100, Train Loss: 0.4019, Val Loss: 0.4274
# Epoch 82/100, Train Loss: 0.3985, Val Loss: 0.4263
# Epoch 83/100, Train Loss: 0.3995, Val Loss: 0.4273
# Epoch 84/100, Train Loss: 0.4007, Val Loss: 0.4263
# Epoch 85/100, Train Loss: 0.4001, Val Loss: 0.4404
# Epoch 86/100, Train Loss: 0.4103, Val Loss: 0.4305
# Epoch 87/100, Train Loss: 0.4056, Val Loss: 0.4254
# Epoch 88/100, Train Loss: 0.4015, Val Loss: 0.4251
# Epoch 89/100, Train Loss: 0.3992, Val Loss: 0.4253
# Epoch 90/100, Train Loss: 0.4011, Val Loss: 0.4247
# Epoch 91/100, Train Loss: 0.3998, Val Loss: 0.4250
# Epoch 92/100, Train Loss: 0.3992, Val Loss: 0.4251
# Epoch 93/100, Train Loss: 0.3965, Val Loss: 0.4231
# Epoch 94/100, Train Loss: 0.3968, Val Loss: 0.4268
# Epoch 95/100, Train Loss: 0.4021, Val Loss: 0.4238
# Epoch 96/100, Train Loss: 0.4015, Val Loss: 0.4339
# Epoch 97/100, Train Loss: 0.3997, Val Loss: 0.4240
# Epoch 98/100, Train Loss: 0.3972, Val Loss: 0.4235
# Epoch 99/100, Train Loss: 0.3971, Val Loss: 0.4223
# Epoch 100/100, Train Loss: 0.3995, Val Loss: 0.4283

# %%
plot_history(train_losses_mae, val_losses_mae)

# %%
model_path = os.path.join(cwd,'saved_model')
make_dir(model_path)

# %%
# Save the model  weightsto a pth file.
torch.save(model_mse.state_dict(), os.path.join(model_path,'CNN_model_mse_weights.pth'))
torch.save(model_mae.state_dict(), os.path.join(model_path,'CNN_model_mae_weights.pth'))

# %% [markdown]
# ### 4. Evaluate the trained model

# %%
# make new model instances for evaluation (best practice)
model_mse_eval = make_CNN_model(X_train.shape[1], n_filters, activation, kernel_size)
model_mae_eval = make_CNN_model(X_train.shape[1], n_filters, activation, kernel_size)

# reload the saved model weights
state_dict_mse = torch.load(os.path.join(model_path,'CNN_model_mse_weights.pth'), weights_only=True)
model_mse_eval.load_state_dict(state_dict_mse)

state_dict_mae = torch.load(os.path.join(model_path,'CNN_model_mae_weights.pth'), weights_only=True)
model_mae_eval.load_state_dict(state_dict_mae)
# Out:
# <All keys matched successfully>

# %%
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=minibatch_size, shuffle=False)

model_mse_eval.to(device).eval()
predictions = []
with torch.no_grad():
   for batch_X, in test_loader:
       batch_X = batch_X.to(device)
       outputs = model_mse_eval(batch_X)
       predictions.append(outputs.cpu().numpy())

y_test_mse_pre = np.concatenate(predictions, axis=0)
y_test_mse_pre = y_test_mse_pre.reshape(y_test_mse_pre.shape[0], 96, 144)
y_test_mse_pre = xr.Dataset(coords={'time': X_test_xr.time.values, 
                              'latitude': X_test_xr.latitude.values, 
                              'longitude': X_test_xr.longitude.values},
                      data_vars=dict(tas=(['time', 'latitude', 'longitude'], y_test_mse_pre)))

model_mae_eval.to(device).eval()
predictions = []
with torch.no_grad():
   for batch_X, in test_loader:
       batch_X = batch_X.to(device)
       outputs = model_mae_eval(batch_X)
       predictions.append(outputs.cpu().numpy())

y_test_mae_pre = np.concatenate(predictions, axis=0)
y_test_mae_pre = y_test_mae_pre.reshape(y_test_mae_pre.shape[0], 96, 144)
y_test_mae_pre = xr.Dataset(coords={'time': X_test_xr.time.values, 
                              'latitude': X_test_xr.latitude.values, 
                              'longitude': X_test_xr.longitude.values},
                      data_vars=dict(tas=(['time', 'latitude', 'longitude'], y_test_mae_pre)))

# %% [markdown]
# First we check whether the ML model can capture the spatial distribution of global temperature

# %%
fig, axes = plt.subplots(figsize=(15,12),ncols=3,nrows=3)

yrs = [2030, 2050, 2100]
vmin, vmax    = -6, 6
cmap = 'RdBu_r'
y_test_mse_pre.tas.sel(time=yrs[0]).plot(ax=axes[0,0], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_mae_pre.tas.sel(time=yrs[0]).plot(ax=axes[0,1], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_xr.tas.sel(time=yrs[0]).plot(ax=axes[0,2], vmin=vmin, vmax=vmax,cmap=cmap)

y_test_mse_pre.tas.sel(time=yrs[1]).plot(ax=axes[1,0], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_mae_pre.tas.sel(time=yrs[1]).plot(ax=axes[1,1], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_xr.tas.sel(time=yrs[1]).plot(ax=axes[1,2], vmin=vmin, vmax=vmax,cmap=cmap)

y_test_mse_pre.tas.sel(time=yrs[2]).plot(ax=axes[2,0], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_mae_pre.tas.sel(time=yrs[2]).plot(ax=axes[2,1], vmin=vmin, vmax=vmax,cmap=cmap)
y_test_xr.tas.sel(time=yrs[2]).plot(ax=axes[2,2], vmin=vmin, vmax=vmax,cmap=cmap)


for i, ax in enumerate(axes.flat):
    # left column: model prediction
    if i % 3 == 0:
        ax.set_title(f'tas prediction (mse, {yrs[i//3]})',fontweight='bold')
    # middle column: model prediction
    elif i % 3 == 1:
        ax.set_title(f'tas prediction (mae, {yrs[i//3]})',fontweight='bold')
    # right column: truth tas from ssp245 simulations
    else:
        ax.set_title(f'tas truth (year = {yrs[i//3]})',fontweight='bold')
plt.tight_layout()

# %% [markdown]
# Then we also check whether the ML model can reproduce the time series of a given location.<br/> Here we take NYC as an example (40.7128° N, 74.0060° W)

# %%
lat = 40.7128
lon = -74.0060%360

fig,ax = plt.subplots(figsize=(9,4))
y_test_xr.sel(latitude=lat,longitude=lon,method='nearest').tas.plot(marker='o',ax=ax,label='truth')
y_test_mse_pre.sel(latitude=lat,longitude=lon,method='nearest').tas.plot(marker='o',ax=ax,label='prediction (mse)')
y_test_mae_pre.sel(latitude=lat,longitude=lon,method='nearest').tas.plot(marker='o',ax=ax,color='tab:brown',label='prediction (mae)')

ax.legend()
ax.set_ylabel('temperature (°C)')
# Out:
# Text(0, 0.5, 'temperature (°C)')

# %% [markdown]
# Let's check the statistical comparison between truth and prediction.

# %%
# combine truth and prediction arrays into a dataframe
nyc_test_xr = y_test_xr.sel(latitude=lat,longitude=lon,method='nearest').tas.values
nyc_test_mse_pre = y_test_mse_pre.sel(latitude=lat,longitude=lon,method='nearest').tas.values
nyc_test_mae_pre = y_test_mae_pre.sel(latitude=lat,longitude=lon,method='nearest').tas.values

df_nyc_test = pd.DataFrame()
df_nyc_test["time"] = y_test_xr.sel(latitude=lat,longitude=lon,method='nearest').tas.to_dataframe().index
df_nyc_test["truth"] = nyc_test_xr
df_nyc_test["prediction_mse"] = nyc_test_mse_pre
df_nyc_test["prediction_mae"] = nyc_test_mae_pre
print(df_nyc_test.head(10))

# summary statistics of the dataframe
df_nyc_test.describe()
# Out:
#    time     truth  prediction_mse  prediction_mae
# 0  2015  1.321960        1.053082        1.117076
# 1  2016  0.608693        1.071751        1.142046
# 2  2017  0.905599        1.091349        1.167542
# 3  2018  0.822795        1.111980        1.193352
# 4  2019  1.061228        1.132917        1.222086
# 5  2020  1.035349        1.155555        1.252937
# 6  2021  1.451701        1.181576        1.283742
# 7  2022  1.484253        1.208041        1.314691
# 8  2023  0.934296        1.235169        1.346000
# 9  2024  1.707011        1.261089        1.378058
#               time      truth  prediction_mse  prediction_mae
# count    86.000000  86.000000       86.000000       86.000000
# mean   2057.500000   2.395548        2.217079        2.555852
# std      24.969982   0.836997        0.691993        0.847001
# min    2015.000000   0.608693        1.053082        1.117076
# 25%    2036.250000   1.691455        1.591320        1.753194
# 50%    2057.500000   2.456390        2.272206        2.688135
# 75%    2078.750000   3.155296        2.881034        3.381821
# max    2100.000000   3.757050        3.181919        3.668950

# %% [markdown]
# Finally we check whether the ML model can capture the time series of global average temperature

# %%
def global_mean_std_plot(X,label,color,ax,var='tas'):
    weights  = np.cos(np.deg2rad(X.latitude))
    tas_mean = X[var].weighted(weights).mean(['latitude', 'longitude']).data
    tas_std  = X[var].weighted(weights).std(['latitude', 'longitude']).data
    
    x = X.time.data

    ax.plot(x, tas_mean, label=label,color=color,linewidth=2)
    ax.fill_between(x,tas_mean+tas_std,tas_mean-tas_std,facecolor=color,alpha=0.2)

# %%
fig,ax = plt.subplots(figsize=(9,4))

global_mean_std_plot(y_test_xr,label='truth',ax=ax,color='tab:blue')
global_mean_std_plot(y_test_mse_pre,label='prediction (mse)',ax=ax,color='tab:orange')
global_mean_std_plot(y_test_mae_pre,label='prediction (mae)',ax=ax,color='tab:brown')

ax.set_xlabel('time')
ax.set_ylabel('global mean temperature (°C)')
ax.legend()
plt.tight_layout()

# %%
# get global mean temperature
def global_mean(X,var='tas'):
    weights  = np.cos(np.deg2rad(X.latitude))
    tas_mean = X['tas'].weighted(weights).mean(['latitude', 'longitude']).data
    return tas_mean

tas_mean_xr = global_mean(y_test_xr)
tas_mean_mse_pre = global_mean(y_test_mse_pre)
tas_mean_mae_pre = global_mean(y_test_mae_pre)

# put into dataframe
df_globalmean_test = pd.DataFrame()
df_globalmean_test["time"] = y_test_xr.sel(latitude=lat,longitude=lon,method='nearest').tas.to_dataframe().index
df_globalmean_test["truth"] = tas_mean_xr
df_globalmean_test["prediction_mse"] = tas_mean_mse_pre
df_globalmean_test["prediction_mae"] = tas_mean_mae_pre
print(df_globalmean_test.head(10))

# summary statistics of the dataframe
df_globalmean_test.describe()
# Out:
#    time     truth  prediction_mse  prediction_mae
# 0  2015  0.724876        0.865017        0.929308
# 1  2016  0.774634        0.877463        0.942134
# 2  2017  0.792321        0.889993        0.955350
# 3  2018  0.905029        0.902771        0.969008
# 4  2019  0.987700        0.915784        0.983100
# 5  2020  1.030206        0.929098        0.997477
# 6  2021  0.935918        0.943295        1.012517
# 7  2022  0.994084        0.957739        1.027710
# 8  2023  0.900831        0.972308        1.042986
# 9  2024  0.845252        0.986839        1.058473
#               time      truth  prediction_mse  prediction_mae
# count    86.000000  86.000000       86.000000       86.000000
# mean   2057.500000   1.564246        1.505340        1.624265
# std      24.969982   0.430099        0.375608        0.408377
# min    2015.000000   0.724876        0.865017        0.929308
# 25%    2036.250000   1.169074        1.164991        1.255073
# 50%    2057.500000   1.635698        1.536706        1.659889
# 75%    2078.750000   1.943204        1.856291        2.008456
# max    2100.000000   2.230782        2.043108        2.199920
