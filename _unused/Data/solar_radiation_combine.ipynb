# %%
import os
import re
import glob
import csv
import pandas as pd
from io import StringIO

# === CONFIG ===
INPUT_DIR = "solar_radiation_csv"
OUTPUT_LONG = "solar_annual_long.csv"
REF_COUNTRIES_PATH = "coordinates_countries_full_209.csv"
# ==============

def load_canonical_names(path):
    if not os.path.exists(path):
        print(f"[WARN] Reference countries file not found: {path}")
        return {}

    ext = os.path.splitext(path)[1].lower()
    if ext == ".csv":
        ref = pd.read_csv(path)
    else:
        ref = pd.read_excel(path)

    cols_lower = {c.lower().strip(): c for c in ref.columns}
    canon_col = None
    for key in ("area", "country", "country name", "name"):
        if key in cols_lower:
            canon_col = cols_lower[key]
            break

    if canon_col is None:
        print("[WARN] Could not find a canonical country column.")
        return {}

    canon_series = ref[canon_col].astype(str)

    def norm(s): return re.sub(r'[^a-z]', '', s.lower())

    mapping = {norm(name): name for name in canon_series}
    print(f"[INFO] Loaded {len(mapping)} canonical names.")
    return mapping

CANON_MAP = load_canonical_names(REF_COUNTRIES_PATH)

def align_to_canonical(name):
    cleaned = name.replace("_", " ").strip()
    if not CANON_MAP: return cleaned
    def norm(s): return re.sub(r"[^a-z]", "", s.lower())
    return CANON_MAP.get(norm(cleaned), cleaned)

def country_from_filename(path):
    base = os.path.basename(path)
    stem = os.path.splitext(base)[0]
    m = re.match(r"^(?P<country>.+?)_(?:-?\d+(?:\.\d+)?)_", stem)
    if m: return align_to_canonical(m.group("country"))
    return align_to_canonical(stem)

def find_header_and_format(text):
    lines = text.replace("\r", "\n").split("\n")
    header_idx = None
    fmt = None

    for i, line in enumerate(lines):
        u = line.upper()
        if ("YEAR" in u) and ("MO" in u or "MONTH" in u) and ("ALLSKY" in u):
            header_idx = i; fmt = "monthly"; break
        if ("YEAR" in u) and ("ALLSKY" in u or "ANN" in u):
            if header_idx is None:
                header_idx = i; fmt = "annual"

    if header_idx is None:
        raise ValueError("No header found for solar radiation CSV.")

    return fmt, header_idx, lines

def parse_monthly_to_annual(text):
    fmt, idx, lines = find_header_and_format(text)
    df = pd.read_csv(StringIO("\n".join(lines[idx:])))
    df.columns = [c.upper() for c in df.columns]

    if fmt == "monthly":
        value_col = None
        for c in df.columns:
            if c.startswith("ALLSKY_SFC_SW_DWN"):
                value_col = c; break
        if value_col is None:
            raise ValueError("Solar value column not found.")

        df["YEAR"] = pd.to_numeric(df["YEAR"], errors="coerce")
        df[value_col] = pd.to_numeric(df[value_col], errors="coerce")
        df = df.dropna(subset=["YEAR", value_col])
        df["YEAR"] = df["YEAR"].astype(int)

        ann = df.groupby("YEAR")[value_col].sum().reset_index()
        ann = ann.rename(columns={"YEAR": "Year", value_col: "ANN"})
        return ann

    else:  # annual
        value_col = None
        for c in df.columns:
            if c.startswith("ALLSKY"):
                value_col = c; break
        if value_col is None:
            raise ValueError("Annual solar data missing ALLSKY column.")

        df["YEAR"] = pd.to_numeric(df["YEAR"], errors="coerce")
        df[value_col] = pd.to_numeric(df[value_col], errors="coerce")
        df = df.dropna()
        return df.rename(columns={"YEAR": "Year", value_col: "ANN"})[["Year", "ANN"]]

def load_year_ann(path):
    with open(path, "r", encoding="utf-8", errors="ignore") as f:
        text = f.read()

    ann = parse_monthly_to_annual(text)
    country = country_from_filename(path)
    ann["Country"] = country
    return ann[["Country", "Year", "ANN"]]

def main():
    files = sorted(glob.glob(os.path.join(INPUT_DIR, "*.csv")))
    parts = []
    for fp in files:
        try:
            parts.append(load_year_ann(fp))
        except Exception as e:
            print(f"[Error {fp}] {e}")

    combined = pd.concat(parts)
    combined = combined.sort_values(["Country", "Year"]).reset_index(drop=True)
    combined.to_csv(OUTPUT_LONG, index=False, encoding="utf-8-sig")

    print(f"[OK] Saved solar radiation long format → {OUTPUT_LONG}")
    print(f"{len(combined)} rows, {combined['Country'].nunique()} countries")

if __name__ == "__main__":
    main()
# Out:
# [INFO] Loaded 209 canonical names.
# [Error solar_radiation_csv\Afghanistan_34.5300_69.1700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Albania_41.3300_19.8200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Algeria_28.0300_1.6600_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Angola_-11.2000_17.8700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Antigua_and_Barbuda_17.1200_-61.8500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Argentina_-38.4200_-63.6200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Armenia_40.0700_45.0400_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Australia_-25.2700_133.7800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Austria_47.5200_14.5500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Azerbaijan_40.1400_47.5800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Bahamas_25.0300_-77.4000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Bahrain_26.0667_50.5577_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Bangladesh_23.6800_90.3600_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Barbados_13.1000_-59.6100_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Belarus_53.7100_27.9500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Belgium-Luxembourg_50.2000_5.2400_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Belgium_50.5000_4.4700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Belize_17.1900_-88.5000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Benin_9.3100_2.3200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Bhutan_27.5100_90.4300_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Bolivia_(Plurinational_State_of)_-16.2900_-63.5900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Bosnia_and_Herzegovina_43.9200_17.6800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Botswana_-22.3300_24.6800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Brazil_-14.2400_-51.9300_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Brunei_Darussalam_4.9000_114.9400_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Bulgaria_42.7300_25.4900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Burkina_Faso_12.2400_-1.5600_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Burundi_-3.3700_29.9200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Cabo_Verde_16.0000_-24.0100_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Cambodia_12.5700_104.9900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Cameroon_7.3700_12.3500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Canada_56.1300_-106.3500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Central_African_Republic_6.6100_20.9400_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Chad_15.4500_18.7300_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Chile_-35.6800_-71.5400_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\China,_Hong_Kong_SAR_22.3200_114.1700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\China,_Taiwan_Province_of_25.0300_121.5700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\China,_mainland_35.0000_103.0000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\China_35.8600_104.2000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Colombia_4.5700_-74.3000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Comoros_-11.6500_43.3300_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Congo_-4.2600_15.2800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Cook_Islands_-21.2100_-159.7800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Costa_Rica_9.7500_-83.7500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Croatia_45.1000_15.2000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Cuba_21.5200_-77.7800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Cyprus_35.1300_33.4300_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Czechia_50.0800_14.4300_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Czechoslovakia_49.0000_20.0000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Côte_d'Ivoire_7.5400_-5.5500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Democratic_People's_Republic_of_Korea_39.0300_125.7500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Democratic_Republic_of_the_Congo_-4.3200_15.3100_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Denmark_56.2600_9.5000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Djibouti_11.8300_42.5900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Dominica_15.3000_-61.3900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Dominican_Republic_18.7400_-70.1600_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Ecuador_-1.8300_-78.1800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\
_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Poland_51.9200_19.1500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Portugal_39.4000_-8.2200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Puerto_Rico_18.4700_-66.1100_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Qatar_25.3500_51.1800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Republic_of_Korea_35.9100_127.7700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Republic_of_Moldova_47.0100_28.8600_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Romania_45.9400_24.9700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Russian_Federation_55.7500_37.6200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Rwanda_-1.9400_29.8700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Réunion_-20.8800_55.4500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Saint_Kitts_and_Nevis_17.3600_-62.7800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Saint_Lucia_13.9100_-60.9600_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Saint_Vincent_and_the_Grenadines_13.2500_-61.2000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Samoa_-13.7700_-172.1000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Sao_Tome_and_Principe_0.1900_6.6100_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Saudi_Arabia_23.8900_45.0800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Senegal_14.5000_-14.4500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Serbia_44.0200_21.0100_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Serbia_and_Montenegro_43.5000_20.5000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Seychelles_-4.6800_55.4900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Sierra_Leone_8.4600_-11.7800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Singapore_1.2900_103.8500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Slovakia_48.6700_19.7000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Slovenia_46.1500_14.9900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Solomon_Islands_-9.4300_159.9600_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Somalia_2.0400_45.3400_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\South_Africa_-30.5600_22.9400_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\South_Sudan_4.8600_31.5700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Spain_40.4600_-3.7500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Sri_Lanka_7.8700_80.7700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Sudan_(former)_15.6000_32.5300_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Sudan_12.8600_30.2200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Suriname_3.9200_-56.0300_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Sweden_60.1300_18.6400_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Switzerland_46.8200_8.2300_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Syrian_Arab_Republic_34.8000_38.9900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Tajikistan_38.8600_71.2800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Thailand_15.8700_100.9900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Timor-Leste_-8.8700_125.7300_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Togo_8.6200_-0.8200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Tokelau_-9.2000_-171.8500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Tonga_-21.1800_-175.2000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Trinidad_and_Tobago_10.6900_-61.2200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Tunisia_33.8900_9.5400_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Turkmenistan_38.9700_59.5600_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Tuvalu_-8.5200_179.2000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Türkiye_38.9600_35.2400_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\USSR_55.7500_37.6200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Uganda_1.3700_32.2900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Ukraine_48.3800_31.1700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\United_Arab_Emirates_23.4200_53.8500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\United_Kingdom_of_Great_Britain_and_Northern_Ireland_54.6000_-2.5000_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\United_Republic_of_Tanzania_-6.3700_34.8900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\United_States_of_America_39.8300_-98.5800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Uruguay_-32.5200_-55.7700_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Uzbekistan_41.3800_64.5900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Vanuatu_-15.3800_166.9600_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Venezuela_(Bolivarian_Republic_of)_6.4200_-66.5900_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Viet_Nam_14.0600_108.2800_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Yemen_15.5500_48.5200_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Yugoslav_SFR_44.8200_20.4600_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Zambia_-13.1300_27.8500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# [Error solar_radiation_csv\Zimbabwe_-19.0200_29.1500_ALLSKY_SFC_SW_DWN_1981_2023.csv] Annual solar data missing ALLSKY column.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 138
#     135     print(f"{len(combined)} rows, {combined['Country'].nunique()} countries")
#     137 if __name__ == "__main__":
# --> 138     main()
#
# Cell In[1], line 130, in main()
#     127     except Exception as e:
#     128         print(f"[Error {fp}] {e}")
# --> 130 combined = pd.concat(parts)
#     131 combined = combined.sort_values(["Country", "Year"]).reset_index(drop=True)
#     132 combined.to_csv(OUTPUT_LONG, index=False, encoding="utf-8-sig")
#
# File c:\Users\Trin Uthaisang\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File c:\Users\Trin Uthaisang\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File c:\Users\Trin Uthaisang\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate
